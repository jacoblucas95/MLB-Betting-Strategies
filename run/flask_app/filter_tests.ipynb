# %%
import os
import numpy as np
import pandas as pd
from app import fix_df_types
from game_filter import date_range

# %%
csvfile = '/Users/james/Desktop/Byte/Baseball/run/setup/data/baseball.csv'
df = pd.read_csv(csvfile, low_memory=False)
df = fix_df_types(df)
df1 = date_range(df=df)

# %%
df1
# Out:
#             date  gameno team visitor_home  team_run_total  total_runs_game  \
# 39442 2018-03-29   19713  CHC            V             8.0             12.0
# 39443 2018-03-29   19713  MIA            H             4.0             12.0
# 39444 2018-03-29   19714  STL            V             4.0             13.0
# 39445 2018-03-29   19714  NYM            H             9.0             13.0
# 39446 2018-03-29   19715  PHI            V             5.0             13.0
# 39447 2018-03-29   19715  ATL            H             8.0             13.0
# 39448 2018-03-29   19716  MIL            V             2.0              3.0
# 39449 2018-03-29   19716   SD            H             1.0              3.0
# 39450 2018-03-29   19717   SF            V             1.0              1.0
# 39451 2018-03-29   19717  LAD            H             0.0              1.0
# 39452 2018-03-29   19718  COL            V             2.0             10.0
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22326 entries, 1 to 44655
# Data columns (total 30 columns):
# Unnamed: 0     22326 non-null int64
# 1st            22325 non-null float64
# 2nd            22325 non-null float64
# 3rd            22325 non-null float64
# 4th            22325 non-null float64
# 5th            22325 non-null object
# 6th            22324 non-null object
# 7th            22323 non-null object
# 8th            22319 non-null object
# 9th            22312 non-null object
# close          22326 non-null float64
# close_ou       22326 non-null float64
# closeouodds    22326 non-null int64
# date           22326 non-null object
# final          22326 non-null object
# open           22326 non-null int64
# open_ou        22185 non-null float64
# openou         141 non-null float64
# openouodds     22326 non-null int64
# pitcher        22303 non-null object
# rot            22326 non-null int64
# rundif         22326 non-null object
# ...

# %%
counter = 0
for index, row in home_team_rows.iterrows():
# Out:
# NYY
# NYY
# NYY
# NYY
# NYY
