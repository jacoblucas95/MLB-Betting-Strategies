# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date

# %%
data = pd.read_pickle('/Users/james/Desktop/Byte/Baseball/run/setup/data/baseball.pickle')

# %%
data['date'] = pd.to_datetime(data['date'], infer_datetime_format=True)

# %%
test_df = data[(data['date'] > '2018-01-01') & (data['date'] <= '2019-5-1')]
test_df
# Out:
#           date  gameno team visitor_home  team_run_total  total_runs_game  \
# 0   2018-03-29   19713  CHC            V             8.0             12.0
# 1   2018-03-29   19713  MIA            H             4.0             12.0
# 2   2018-03-29   19714  STL            V             4.0             13.0
# 3   2018-03-29   19714  NYM            H             9.0             13.0
# 4   2018-03-29   19715  PHI            V             5.0             13.0
# 5   2018-03-29   19715  ATL            H             8.0             13.0
# 6   2018-03-29   19716  MIL            V             2.0              3.0
# 7   2018-03-29   19716   SD            H             1.0              3.0
# 8   2018-03-29   19717   SF            V             1.0              1.0
# 9   2018-03-29   19717  LAD            H             0.0              1.0
# 10  2018-03-29   19718  COL            V             2.0             10.0
# 11  2018-03-29   19718  ARI            H             8.0             10.0
# ...

# %%
ax = plt.gca()
data.plot(kind='line', x='date', y='gameno', color='red', ax=ax)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
data[(data['date'] > '2018-1-1 01:00:00') & (data['date'] <= '2019-5-1 04:00:00')]
# Out:
#           date  gameno team visitor_home  team_run_total  total_runs_game  \
# 0   2018-03-29   19713  CHC            V             8.0             12.0
# 1   2018-03-29   19713  MIA            H             4.0             12.0
# 2   2018-03-29   19714  STL            V             4.0             13.0
# 3   2018-03-29   19714  NYM            H             9.0             13.0
# 4   2018-03-29   19715  PHI            V             5.0             13.0
# 5   2018-03-29   19715  ATL            H             8.0             13.0
# 6   2018-03-29   19716  MIL            V             2.0              3.0
# 7   2018-03-29   19716   SD            H             1.0              3.0
# 8   2018-03-29   19717   SF            V             1.0              1.0
# 9   2018-03-29   19717  LAD            H             0.0              1.0
# 10  2018-03-29   19718  COL            V             2.0             10.0
# 11  2018-03-29   19718  ARI            H             8.0             10.0
# ...
