# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date

# %%
data = pd.read_pickle('/Users/james/Desktop/Byte/Baseball/run/setup/data/baseball.pickle')

# %%
# data.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44638 entries, 0 to 285
# Data columns (total 17 columns):
# date                     44638 non-null datetime64[ns]
# gameno                   44638 non-null int64
# team                     44638 non-null object
# visitor_home             44638 non-null object
# team_run_total           44636 non-null float64
# total_runs_game          44636 non-null float64
# money_line_close         44638 non-null float64
# money_line_open          44638 non-null int64
# over_under_line_close    44638 non-null float64
# over_under_line_open     44638 non-null float64
# over_under_odds_close    44638 non-null int64
# over_under_odds_open     44638 non-null int64
# pitcher                  44595 non-null object
# rot                      44638 non-null int64
# run_dif_game             44636 non-null float64
# run_line_close           24908 non-null float64
# run_line_odds_close      24908 non-null float64
# dtypes: datetime64[ns](1), float64(8), int64(5), object(3)
# memory usage: 6.1+ MB

# %%
ax = plt.gca()
data.plot(kind='line', x='date', y='gameno', color='red', ax=ax)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
new = data[(data['date'] > '2018-5-1 00:00:00') & (data['date'] <= '2018-5-2 00:00:00')]

# %%
filtered = new[(data['date'] > '2018-5-1 00:00:00') & (data['date'] <= '2018-5-2 00:00:00')]
# Out:
#           date  gameno team visitor_home  team_run_total  total_runs_game  \
# 868 2018-05-02   20147  COL            V            11.0             13.0
# 869 2018-05-02   20147  CHC            H             2.0             13.0
# 870 2018-05-02   20148   SD            V             4.0             13.0
# 871 2018-05-02   20148   SF            H             9.0             13.0
# 872 2018-05-02   20149  PIT            V             3.0             12.0
# 873 2018-05-02   20149  WAS            H             9.0             12.0
# 874 2018-05-02   20150  ATL            V             7.0              7.0
# 875 2018-05-02   20150  NYM            H             0.0              7.0
# 876 2018-05-02   20151  PHI            V             6.0              6.0
# 877 2018-05-02   20151  MIA            H             0.0              6.0
# 878 2018-05-02   20152  MIL            V             3.0              4.0
# 879 2018-05-02   20152  CIN            H             1.0              4.0
# 880 2018-05-02   20153  LAD            V             2.0              3.0
# 881 2018-05-02   20153  ARI            H             1.0              3.0
# 882 2018-05-02   20154   KC            V             4.0              9.0
# 883 2018-05-02   20154  BOS            H             5.0              9.0
# 884 2018-05-02   20155   TB            V             2.0              5.0
# 885 2018-05-02   20155  DET            H             3.0              5.0
# 886 2018-05-02   20156  TOR            V             0.0              4.0
# 887 2018-05-02   20156  MIN            H             4.0              4.0
# 888 2018-05-02   20157  TEX            V             4.0             16.0
# 889 2018-05-02   20157  CLE            H            12.0             16.0
# 890 2018-05-02   20158  NYY            V             4.0              4.0
# 891 2018-05-02   20158  HOU            H             0.0              4.0
# 892 2018-05-02   20159  BAL            V             7.0             17.0
# 893 2018-05-02   20159  LAA            H            10.0             17.0
# 894 2018-05-02   20160  OAK            V             3.0              5.0
# 895 2018-05-02   20160  SEA            H             2.0              5.0
# 896 2018-05-02   20161  CWS            V             2.0              5.0
# 897 2018-05-02   20161  STL            H             3.0              5.0
#
#      money_line_close  money_line_open  over_under_line_close  \
# 868             200.0              163                   10.5
# 869            -225.0             -183                   10.5
# 870             108.0              131                    8.0
# 871            -118.0             -146                    8.0
# 872             170.0              176                    7.5
# 873            -190.0             -201                    7.5
# 874             136.0              163                    7.5
# 875            -151.0             -183                    7.5
# 876            -177.0             -160                    7.0
# 877             157.0              140                    7.0
# 878            -111.0              112                    9.5
# 879             101.0             -122                    9.5
# 880            -102.0              120                    7.5
# 881            -108.0             -135                    7.5
# 882             160.0              176                   11.0
# 883            -180.0             -196                   11.0
# 884            -128.0             -123                    8.0
# 885             113.0              113                    8.0
# 886            -108.0             -114                    9.0
# 887            -102.0              104                    9.0
# 888             262.0              275                    9.0
# 889            -302.0             -315                    9.0
# 890            -129.0              104                    8.5
# 891             114.0             -114                    8.5
# 892             137.0              123                    7.5
# 893            -152.0             -138                    7.5
# 894             152.0              164                    8.0
# 895            -172.0             -184                    8.0
# 896             230.0              229                    9.5
# 897            -260.0             -259                    9.5
#
#      over_under_line_open  over_under_odds_close  over_under_odds_open  \
# 868                  10.5                   -105                  -105
# 869                  10.5                   -115                  -115
# 870                   8.0                   -115                  -120
# 871                   8.0                   -105                   100
# 872                   7.5                   -119                  -105
# 873                   7.5                   -101                  -115
# 874                   7.0                   -101                  -120
# 875                   7.0                   -119                   100
# 876                   8.0                   -125                   100
# 877                   8.0                    105                  -120
# 878                   9.5                   -110                  -110
# 879                   9.5                   -110                  -110
# 880                   8.0                   -101                  -110
# 881                   8.0                   -119                  -110
# 882                   9.0                    105                  -120
# 883                   9.0                   -125                   100
# 884                   8.0                   -121                  -110
# 885                   8.0                    101                  -110
# 886                   9.5                   -115                   100
# 887                   9.5                   -105                  -120
# 888                   8.0                   -110                  -105
# 889                   8.0                   -110                  -115
# 890                   8.0                   -103                   100
# 891                   8.0                   -117                  -120
# 892                   8.5                    100                   100
# 893                   8.5                   -120                  -120
# 894                   8.0                   -105                  -120
# 895                   8.0                   -115                   100
# 896                   8.5                   -105                  -120
# 897                   8.5                   -115                   100
#
#           pitcher  rot  run_dif_game  run_line_close  run_line_odds_close
# 868   TANDERSON-L  901           9.0             1.5                105.0
# 869    YDARVISH-R  902          -9.0            -1.5               -125.0
# 870    CRICHARD-L  903          -5.0             1.5               -195.0
# 871    DHOLLAND-L  904           5.0            -1.5                166.0
# 872       INOVA-R  905          -6.0             1.5               -130.0
# 873  SSTRASBURG-R  906           6.0            -1.5                110.0
# 874    SNEWCOMB-L  907           7.0             1.5               -160.0
# 875     JDEGROM-R  908          -7.0            -1.5                140.0
# 876       ANOLA-R  909           6.0            -1.5               -110.0
# 877      JURENA-R  910          -6.0             1.5               -110.0
# 878      WMILEY-L  911           2.0            -1.5                139.0
# 879   LCASTILLO-R  912          -2.0             1.5               -159.0
# 880        HRYU-L  913           1.0             1.5               -215.0
# 881     ZGODLEY-R  914          -1.0            -1.5                180.0
# 882      DDUFFY-L  915          -1.0             1.5               -119.0
# 883   DPOMERANZ-L  916           1.0            -1.5               -101.0
# 884      BSNELL-L  917          -1.0            -1.5                126.0
# 885     MFULMER-R  918           1.0             1.5               -146.0
# 886    MSTROMAN-R  919          -4.0            -1.5                144.0
# 887     FROMERO-R  920           4.0             1.5               -165.0
# 888      MMOORE-L  921          -8.0             1.5                126.0
# 889     CKLUBER-R  922           8.0            -1.5               -145.0
# 890   LSEVERINO-R  923           4.0            -1.5                125.0
# 891    DKEUCHEL-L  924          -4.0             1.5               -145.0
# 892      DBUNDY-R  925          -3.0             1.5               -160.0
# 893     AHEANEY-L  926           3.0            -1.5                140.0
# 894   BANDERSON-L  927           1.0             1.5               -135.0
# 895     JPAXTON-L  928          -1.0            -1.5                115.0
# 896    LGIOLITO-R  929          -1.0             1.5                119.0
# 897   CMARTINEZ-R  930           1.0            -1.5               -139.0

# %%
# Out:
#           date  gameno team visitor_home  team_run_total  total_runs_game  \
# 869 2018-05-02   20147  CHC            H             2.0             13.0
# 871 2018-05-02   20148   SF            H             9.0             13.0
# 873 2018-05-02   20149  WAS            H             9.0             12.0
# 875 2018-05-02   20150  NYM            H             0.0              7.0
# 876 2018-05-02   20151  PHI            V             6.0              6.0
# 878 2018-05-02   20152  MIL            V             3.0              4.0
# 880 2018-05-02   20153  LAD            V             2.0              3.0
# 881 2018-05-02   20153  ARI            H             1.0              3.0
# 883 2018-05-02   20154  BOS            H             5.0              9.0
# 884 2018-05-02   20155   TB            V             2.0              5.0
# 886 2018-05-02   20156  TOR            V             0.0              4.0
# 887 2018-05-02   20156  MIN            H             4.0              4.0
# 889 2018-05-02   20157  CLE            H            12.0             16.0
# 890 2018-05-02   20158  NYY            V             4.0              4.0
# 893 2018-05-02   20159  LAA            H            10.0             17.0
# 895 2018-05-02   20160  SEA            H             2.0              5.0
# 897 2018-05-02   20161  STL            H             3.0              5.0
#
#      money_line_close  money_line_open  over_under_line_close  \
# 869            -225.0             -183                   10.5
# 871            -118.0             -146                    8.0
# 873            -190.0             -201                    7.5
# 875            -151.0             -183                    7.5
# 876            -177.0             -160                    7.0
# 878            -111.0              112                    9.5
# 880            -102.0              120                    7.5
# 881            -108.0             -135                    7.5
# 883            -180.0             -196                   11.0
# 884            -128.0             -123                    8.0
# 886            -108.0             -114                    9.0
# 887            -102.0              104                    9.0
# 889            -302.0             -315                    9.0
# 890            -129.0              104                    8.5
# 893            -152.0             -138                    7.5
# 895            -172.0             -184                    8.0
# 897            -260.0             -259                    9.5
#
#      over_under_line_open  over_under_odds_close  over_under_odds_open  \
# 869                  10.5                   -115                  -115
# 871                   8.0                   -105                   100
# 873                   7.5                   -101                  -115
# 875                   7.0                   -119                   100
# 876                   8.0                   -125                   100
# 878                   9.5                   -110                  -110
# 880                   8.0                   -101                  -110
# 881                   8.0                   -119                  -110
# 883                   9.0                   -125                   100
# 884                   8.0                   -121                  -110
# 886                   9.5                   -115                   100
# 887                   9.5                   -105                  -120
# 889                   8.0                   -110                  -115
# 890                   8.0                   -103                   100
# 893                   8.5                   -120                  -120
# 895                   8.0                   -115                   100
# 897                   8.5                   -115                   100
#
#           pitcher  rot  run_dif_game  run_line_close  run_line_odds_close
# 869    YDARVISH-R  902          -9.0            -1.5               -125.0
# 871    DHOLLAND-L  904           5.0            -1.5                166.0
# 873  SSTRASBURG-R  906           6.0            -1.5                110.0
# 875     JDEGROM-R  908          -7.0            -1.5                140.0
# 876       ANOLA-R  909           6.0            -1.5               -110.0
# 878      WMILEY-L  911           2.0            -1.5                139.0
# 880        HRYU-L  913           1.0             1.5               -215.0
# 881     ZGODLEY-R  914          -1.0            -1.5                180.0
# 883   DPOMERANZ-L  916           1.0            -1.5               -101.0
# 884      BSNELL-L  917          -1.0            -1.5                126.0
# 886    MSTROMAN-R  919          -4.0            -1.5                144.0
# 887     FROMERO-R  920           4.0             1.5               -165.0
# 889     CKLUBER-R  922           8.0            -1.5               -145.0
# 890   LSEVERINO-R  923           4.0            -1.5                125.0
# 893     AHEANEY-L  926           3.0            -1.5                140.0
# 895     JPAXTON-L  928          -1.0            -1.5                115.0
# 897   CMARTINEZ-R  930           1.0            -1.5               -139.0
