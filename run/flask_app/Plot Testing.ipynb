# %%
import numpy as np
import pandas as pd
from datetime import date
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_pickle('/Users/james/Desktop/Byte/Baseball/run/setup/data/dataset.pickle')

# %%
data['date'] = pd.to_datetime(data['date'], infer_datetime_format=True)

# %%
test_df = data[(data['date'] > '2018-01-01') & (data['date'] <= '2019-5-1')]

# %%
# filtered = test_df[test_df['v_money_line_close'] >= 200]

# %%
test_df
# Out:
#             date  gameno visitor v_team  v_team_run_total  v_money_line_close  \
# 19721 2018-03-29   19721       V    CHC               8.0              -200.0
# 19722 2018-03-29   19722       V    STL               4.0               123.0
# 19723 2018-03-29   19723       V    PHI               5.0              -131.0
# 19724 2018-03-29   19724       V    MIL               2.0              -131.0
# 19725 2018-03-29   19725       V     SF               1.0               266.0
# 19726 2018-03-29   19726       V    COL               2.0              -101.0
# 19727 2018-03-29   19727       V    MIN               2.0               112.0
# 19728 2018-03-29   19728       V    HOU               4.0              -160.0
# 19729 2018-03-29   19729       V    NYY               6.0              -171.0
# 19730 2018-03-29   19730       V    BOS               4.0              -173.0
# 19731 2018-03-29   19731       V    LAA               5.0              -118.0
# ...

# %%
ax = plt.gca()
data.plot(kind='line', x='date', y='gameno', color='red', ax=ax)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
test_df['h_money_line_close']
# Out:
# 19721    175.0
# 19722   -138.0
# 19723    116.0
# 19724    116.0
# 19725   -306.0
# 19726   -109.0
# 19727   -127.0
# 19728    140.0
# 19729    151.0
# 19730    153.0
# 19731    108.0
# 19732   -140.0
# 19733    160.0
# 19734    175.0
# 19735   -101.0
# 19736   -143.0
# 19737   -163.0
# 19738    103.0
# 19739    122.0
# 19740    126.0
# 19741    150.0
# 19742    104.0
# 19743    190.0
# 19744    114.0
# 19745   -117.0
# 19746    130.0
# 19747   -115.0
# 19748    185.0
# 19749   -151.0
# 19750    110.0
#          ...
# 22296    118.0
# 22297   -111.0
# 22298   -120.0
# 22299   -129.0
# 22300   -172.0
# 22301    106.0
# 22302   -122.0
# 22303   -105.0
# 22304   -160.0
# 22305   -194.0
# 22306    165.0
# 22307   -135.0
# 22308   -148.0
# 22309    122.0
# 22310    122.0
# 22311    118.0
# 22312   -170.0
# 22313   -150.0
# 22314   -106.0
# 22315   -120.0
# 22316    160.0
# 22317    170.0
# 22318   -160.0
# 22319   -104.0
# 22320   -180.0
# 22321   -116.0
# 22322   -117.0
# ...
