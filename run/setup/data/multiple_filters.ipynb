# %%
import pandas as pd
import numpy as np
from datetime import date

# %%
df = pd.read_pickle('baseball.pickle')

# %%
def date_range(df=df, start_date=date(2018,1,1), end_date=date(2019,12,31)):
    df['date'] = pd.to_datetime(df['date'])
    df2 = df[df['date'].isin(pd.date_range(start_date,end_date))]
    return df2

# %%
def home_away(h_a,df=df):
    df2 = df.loc[(df['visitor_home'] == h_a)]
    return df2

# %%
def fav_dog(f_d, df=df):
    if f_d == 'f':
        return df.loc[df['money_line_close'] < 0]
    else:
        return df.loc[df['money_line_close'] > 0]

# %%
class Filter:
    
    def __init__(self, start_date, end_date, visitor_home, favorite_underdog):
        self.start_date = start_date
        self.end_date = end_date
        self.visitor_home = visitor_home
        self.favorite_underdog = favorite_underdog
        self.df = df

    def get_df_date_range(self):
        self.df['date'] = pd.to_datetime(self.df['date'])
        df_date_range = self.df[self.df['date'].isin(pd.date_range(self.start_date, self.end_date))]
        return df_date_range
    
    def get_df_ml_fav(self):
        df_date_range = self.get_df_date_range()
        df_ml_fav = df_date_range.loc[(df_date_range['visitor_home'] == self.visitor_home) & (df_date_range['money_line_close'] < 0)]
        fav_gameno_list = df_ml_fav['gameno'].tolist()
        return fav_gameno_list
    
    def get_df_ml_dog(self):
        df_date_range = self.get_df_date_range()
        df_ml_dog = df_date_range.loc[(df_date_range['visitor_home'] == self.visitor_home) & (df_date_range['money_line_close'] > 0)]
        dog_gameno_list = df_ml_dog['gameno'].tolist()
        return dog_gameno_list
    
    def get_df_rl_fav(self):
        df_date_range = self.get_df_date_range()
        df_rl_fav = df_date_range.loc[(df_date_range['visitor_home'] == self.visitor_home) & (df_date_range['run_line_odds_close'] < 0)]
        fav_gameno_list = df_rl_fav['gameno'].tolist()
        return fav_gameno_list
        
    def get_df_rl_dog(self):
        df_date_range = self.get_df_date_range()
        df_rl_dog = df_date_range.loc[(df_date_range['visitor_home'] == self.visitor_home) & (df_date_range['run_line_odds_close'] > 0)]
        fav_gameno_list = df_rl_dog['gameno'].tolist()
        return fav_gameno_list
    
    def get_df_o_fav(self):
        df_date_range = self.get_df_date_range()
        df_v = df_date_range.loc[df_date_range['visitor_home'] == 'V']
        df_h = df_date_range.loc[df_date_range['visitor_home'] == 'H']
        df_h.columns = ['h_date', 'gameno', 'h_team', 'h_visitor_home', 'h_team_run_total',
       'h_total_runs_game', 'h_money_line_close', 'h_money_line_open',
       'h_over_under_line_close', 'h_over_under_line_open',
       'h_over_under_odds_close', 'h_over_under_odds_open', 'h_pitcher', 'h_rot',
       'h_run_dif_game', 'h_run_line_close', 'h_run_line_odds_close']
        df2 = pd.merge(df_v, df_h, on='gameno', how='right')
        gameno_list = []
        for index, row in df2.iterrows():
            if row['over_under_odds_close'] > row['h_over_under_odds_close']:
                gameno = row['gameno']
                gameno_list.append(gameno)
            else:
                pass
        return gameno_list
        
    def get_df_u_fav(self):
        pass

# %%
df.columns
# Out:
# Index(['date', 'gameno', 'team', 'visitor_home', 'team_run_total',
#        'total_runs_game', 'money_line_close', 'money_line_open',
#        'over_under_line_close', 'over_under_line_open',
#        'over_under_odds_close', 'over_under_odds_open', 'pitcher', 'rot',
#        'run_dif_game', 'run_line_close', 'run_line_odds_close'],
#       dtype='object')

# %%
f = Filter(date(2016, 1, 1), date(2017,1,1), 'H', 'fav')
f.get_df_o_fav()
# Out:
#            date  gameno team visitor_home  team_run_total  total_runs_game  \
# 0    2016-04-03   14792  STL            V             1.0              5.0
# 1    2016-04-03   14793  TOR            V             5.0              8.0
# 2    2016-04-03   14794  NYM            V             3.0              7.0
# 3    2016-04-04   14795   SF            V            12.0             15.0
# 4    2016-04-04   14796  WAS            V             4.0              7.0
# 5    2016-04-04   14797  PHI            V             2.0              8.0
# 6    2016-04-04   14798  LAD            V            15.0             15.0
# 7    2016-04-04   14799  COL            V            10.0             15.0
# 8    2016-04-04   14800  MIN            V             2.0              5.0
# 9    2016-04-04   14801  SEA            V             2.0              5.0
# 10   2016-04-04   14802  TOR            V             5.0              8.0
# 11   2016-04-04   14803  CWS            V             4.0              7.0
# 12   2016-04-04   14804  CHC            V             9.0              9.0
# 13   2016-04-05   14805  STL            V             5.0             11.0
# 14   2016-04-05   14806   SF            V             2.0              3.0
# 15   2016-04-05   14807  COL            V             6.0             17.0
# 16   2016-04-05   14808  LAD            V             3.0              3.0
# 17   2016-04-05   14809  TOR            V             2.0              5.0
# 18   2016-04-05   14810  SEA            V            10.0             12.0
# 19   2016-04-05   14811  CWS            V             5.0              9.0
# 20   2016-04-05   14812  NYM            V             2.0              2.0
# 21   2016-04-05   14813  DET            V             8.0             15.0
# 22   2016-04-05   14814  CHC            V             6.0              7.0
# 23   2016-04-05   14815  HOU            V             5.0              8.0
# 24   2016-04-05   14816  BOS            V             6.0              8.0
# 25   2016-04-06   14817   SF            V             3.0              7.0
# 26   2016-04-06   14818  COL            V             4.0              7.0
# 27   2016-04-06   14819  STL            V             1.0              6.0
# 28   2016-04-06   14820  WAS            V             3.0              4.0
# 29   2016-04-06   14821  PHI            V             2.0              5.0
# ...         ...     ...  ...          ...             ...              ...
# 2432 2016-10-07   17224   SF            V             0.0              1.0
# 2433 2016-10-07   17225  BOS            V             0.0              6.0
# 2434 2016-10-07   17226  TOR            V             5.0              8.0
# 2435 2016-10-08   17227   SF            V             2.0              7.0
# 2436 2016-10-09   17228  TEX            V             6.0             13.0
# 2437 2016-10-09   17229  LAD            V             2.0              7.0
# 2438 2016-10-10   17230  WAS            V             8.0             11.0
# 2439 2016-10-10   17231  CHC            V             5.0             11.0
# 2440 2016-10-10   17232  CLE            V             4.0              7.0
# 2441 2016-10-11   17233  WAS            V             5.0             11.0
# 2442 2016-10-11   17234  CHC            V             6.0             11.0
# 2443 2016-10-13   17235  LAD            V             4.0              7.0
# 2444 2016-10-14   17236  TOR            V             0.0              2.0
# 2445 2016-10-15   17237  LAD            V             4.0             12.0
# 2446 2016-10-15   17238  TOR            V             1.0              3.0
# 2447 2016-10-16   17239  LAD            V             1.0              1.0
# 2448 2016-10-17   17240  CLE            V             4.0              6.0
# 2449 2016-10-18   17241  CHC            V             0.0              6.0
# 2450 2016-10-18   17242  CLE            V             1.0              6.0
# 2451 2016-10-19   17243  CHC            V            10.0             12.0
# 2452 2016-10-19   17244  CLE            V             3.0              3.0
# 2453 2016-10-20   17245  CHC            V             8.0             12.0
# 2454 2016-10-22   17246  LAD            V             0.0              5.0
# 2455 2016-10-25   17247  CHC            V             0.0              6.0
# 2456 2016-10-26   17248  CHC            V             5.0              6.0
# 2457 2016-10-28   17249  CLE            V             1.0              1.0
# 2458 2016-10-29   17250  CLE            V             7.0              9.0
# 2459 2016-10-30   17251  CLE            V             2.0              5.0
# 2460 2016-11-01   17252  CHC            V             9.0             12.0
# 2461 2016-11-02   17253  CHC            V             8.0             15.0
#
#       money_line_close  money_line_open  over_under_line_close  \
# 0                109.0             -115                    6.5
# 1                111.0             -115                    7.0
# 2               -120.0             -119                    8.0
# 3               -175.0             -185                    8.0
# 4               -180.0             -200                    7.0
# 5                155.0              125                    7.5
# 6               -200.0             -175                    6.0
# 7                155.0              205                    8.0
# 8                109.0              109                    9.0
# 9                111.0              110                    8.0
# 10               107.0             -109                    8.5
# 11              -145.0              110                    7.0
# 12              -145.0             -145                    7.0
# 13               102.0             -115                    7.0
# 14              -158.0             -140                    8.0
# 15               115.0              145                    9.0
# 16              -115.0             -140                    7.5
# 17              -107.0              110                    8.5
# 18              -103.0              110                    9.0
# 19              -113.0             -115                    7.5
# 20              -127.0             -125                    8.5
# 21              -107.0             -115                    7.5
# 22              -125.0             -130                    7.5
# 23              -123.0             -130                    6.5
# 24               113.0             -104                    6.0
# 25              -141.0             -132                    9.0
# 26               125.0              162                    8.5
# 27               102.0             -105                    7.5
# 28              -190.0             -191                    7.0
# 29               117.0              115                    8.0
# ...                ...              ...                    ...
# 2432             150.0              165                    6.5
# 2433             104.0             -105                    7.5
# 2434             126.0              110                    8.0
# 2435             175.0              155                    7.5
# 2436             180.0              175                    9.0
# 2437            -140.0             -115                    7.5
# 2438             125.0              135                    7.5
# 2439            -102.0              116                    6.5
# 2440             130.0              125                    9.0
# 2441             235.0              230                    7.0
# 2442            -120.0             -130                    7.5
# 2443             117.0              125                    7.0
# 2444             125.0              115                    7.5
# 2445             195.0              175                    7.5
# 2446            -134.0             -125                    8.5
# 2447            -140.0             -131                    6.5
# 2448             157.0              175                    8.5
# 2449             107.0             -115                    6.5
# 2450             104.0              103                    7.5
# 2451             104.0             -120                    7.5
# 2452             154.0              150                    8.5
# 2453            -170.0             -157                    7.0
# 2454            -130.0             -140                    6.0
# 2455             101.0             -115                    6.5
# 2456            -164.0             -132                    8.0
# 2457             195.0              165                    8.5
# 2458             111.0              115                    6.5
# 2459             195.0              189                    6.5
# 2460            -156.0             -137                    7.5
# 2461            -134.0             -110                    6.5
#
#       over_under_line_open  ...  h_money_line_open  h_over_under_line_close  \
# 0                      6.5  ...                105                      6.5
# 1                      7.0  ...                105                      7.0
# 2                      7.0  ...                109                      8.0
# 3                      7.0  ...                165                      8.0
# 4                      6.5  ...                175                      7.0
# 5                      8.5  ...               -140                      7.5
# 6                      5.5  ...                155                      6.0
# 7                      7.0  ...               -230                      8.0
# 8                      8.0  ...               -119                      9.0
# 9                      7.5  ...               -125                      8.0
# 10                     7.5  ...               -101                      8.5
# 11                     6.0  ...               -125                      7.0
# 12                     6.5  ...                130                      7.0
# 13                     7.5  ...                105                      7.0
# 14                     8.0  ...                125                      8.0
# 15                     8.5  ...               -165                      9.0
# 16                     6.5  ...                125                      7.5
# 17                     8.0  ...               -125                      8.5
# 18                     8.5  ...               -120                      9.0
# 19                     7.5  ...                105                      7.5
# 20                     7.5  ...                110                      8.5
# 21                     7.5  ...                105                      7.5
# 22                     7.5  ...                115                      7.5
# 23                     7.0  ...                115                      6.5
# 24                     6.5  ...               -106                      6.0
# 25                     8.5  ...                117                      9.0
# 26                     8.5  ...               -182                      8.5
# 27                     7.5  ...               -105                      7.5
# 28                     7.5  ...                171                      7.0
# 29                     8.0  ...               -130                      8.0
# ...                    ...  ...                ...                      ...
# 2432                   7.0  ...               -185                      6.5
# 2433                   7.0  ...               -105                      7.5
# 2434                   9.0  ...               -120                      8.0
# 2435                   7.0  ...               -175                      7.5
# 2436                   9.5  ...               -200                      9.0
# 2437                   7.5  ...                105                      7.5
# 2438                   7.5  ...               -150                      7.5
# 2439                   6.0  ...               -131                      6.5
# 2440                   9.5  ...               -140                      9.0
# 2441                   6.5  ...               -265                      7.0
# 2442                   7.5  ...                115                      7.5
# 2443                   7.0  ...               -140                      7.0
# 2444                   7.5  ...               -130                      7.5
# 2445                   7.0  ...               -200                      7.5
# 2446                   8.5  ...                110                      8.5
# 2447                   6.5  ...                116                      6.5
# 2448                   9.0  ...               -200                      8.5
# 2449                   6.5  ...                105                      6.5
# 2450                   7.5  ...               -113                      7.5
# 2451                   7.5  ...                110                      7.5
# 2452                   8.0  ...               -170                      8.5
# 2453                   7.0  ...                142                      7.0
# 2454                   6.5  ...                125                      6.0
# 2455                   6.5  ...                105                      6.5
# 2456                   7.0  ...                117                      8.0
# 2457                   7.5  ...               -185                      8.5
# 2458                   6.5  ...               -130                      6.5
# 2459                   6.5  ...               -214                      6.5
# 2460                   7.0  ...                122                      7.5
# 2461                   7.0  ...                100                      6.5
#
#      h_over_under_line_open  h_over_under_odds_close  h_over_under_odds_open  \
# 0                       6.5                     -110                    -115
# 1                       7.0                      110                    -105
# 2                       7.0                     -117                     100
# 3                       7.0                     -113                     100
# 4                       6.5                     -105                    -120
# 5                       8.5                     -120                    -120
# 6                       5.5                     -120                    -110
# 7                       7.0                     -110                    -110
# 8                       8.0                     -110                    -110
# 9                       7.5                      105                    -120
# 10                      7.5                     -120                     100
# 11                      6.0                     -115                     105
# 12                      6.5                     -130                    -115
# 13                      7.5                     -105                    -120
# 14                      8.0                      100                    -115
# 15                      8.5                     -115                    -115
# 16                      6.5                     -130                     100
# 17                      8.0                     -110                     100
# 18                      8.5                      100                    -115
# 19                      7.5                     -105                    -120
# 20                      7.5                      100                     100
# 21                      7.5                      105                    -120
# 22                      7.5                     -120                    -110
# 23                      7.0                     -105                    -110
# 24                      6.5                     -110                    -115
# 25                      8.5                     -110                    -115
# 26                      8.5                      100                    -105
# 27                      7.5                     -110                    -120
# 28                      7.5                     -105                    -125
# 29                      8.0                     -110                    -105
# ...                     ...                      ...                     ...
# 2432                    7.0                     -105                    -123
# 2433                    7.0                     -110                     105
# 2434                    9.0                     -105                     100
# 2435                    7.0                     -120                     100
# 2436                    9.5                     -120                    -120
# 2437                    7.5                     -125                    -123
# 2438                    7.5                     -110                     100
# 2439                    6.0                     -105                    -110
# 2440                    9.5                     -110                    -110
# 2441                    6.5                     -120                    -105
# 2442                    7.5                      100                    -110
# 2443                    7.0                     -130                    -110
# 2444                    7.5                     -120                    -115
# 2445                    7.0                     -103                    -108
# 2446                    8.5                      100                    -113
# 2447                    6.5                     -115                    -115
# 2448                    9.0                      100                    -120
# 2449                    6.5                      105                    -105
# 2450                    7.5                     -110                    -111
# 2451                    7.5                     -105                    -125
# 2452                    8.0                     -110                     100
# 2453                    7.0                      105                    -115
# 2454                    6.5                      100                    -110
# 2455                    6.5                     -125                    -105
# 2456                    7.0                     -122                    -107
# 2457                    7.5                     -115                    -115
# 2458                    6.5                     -115                    -110
# 2459                    6.5                     -115                    -107
# 2460                    7.0                     -105                     103
# 2461                    7.0                     -110                     100
#
#         h_pitcher  h_rot h_run_dif_game h_run_line_close h_run_line_odds_close
# 0      FLIRIANO-L    902            3.0             -1.5                 190.0
# 1       CARCHER-R    904           -2.0             -1.5                 180.0
# 2      EVOLQUEZ-R    908            1.0              1.5                -165.0
# 3      WPERALTA-R    952           -9.0              1.5                -110.0
# 4      JTEHERAN-R    954           -1.0              1.5                -113.0
# 5     RIGLESIAS-R    956            4.0             -1.5                 120.0
# 6         TROSS-R    958          -15.0              1.5                -109.0
# 7      ZGREINKE-R    960           -5.0             -1.5                 120.0
# 8      CTILLMAN-R    964            1.0             -1.5                 170.0
# 9       CHAMELS-L    966            1.0             -1.5                 170.0
# 10       DSMYLY-L    970           -2.0             -1.5                 180.0
# 11        RHILL-L    972           -1.0              1.5                -135.0
# 12    GRICHARDS-R    974           -9.0              1.5                -135.0
# 13       JNIESE-L    902            1.0             -1.5                 195.0
# 14      JNELSON-R    904           -1.0              1.5                -115.0
# 15      SMILLER-R    906            5.0             -1.5                 155.0
# 16     JSHIELDS-R    908           -3.0              1.5                -160.0
# 17    JODORIZZI-R    910            1.0              1.5                -170.0
# 18       MPEREZ-L    912           -8.0             -1.5                 185.0
# 19     CBASSITT-R    914           -1.0              1.5                -165.0
# 20       CYOUNG-R    916           -2.0              1.5                -140.0
# 21        WCHEN-L    918           -1.0              1.5                -175.0
# 22      AHEANEY-L    920           -5.0              1.5                -160.0
# 23      MTANAKA-R    922           -2.0              1.5                -168.0
# 24      CKLUBER-R    924           -4.0             -1.5                 205.0
# 25     JUNGMANN-R    952            1.0              1.5                -140.0
# 26      PCORBIN-L    954           -1.0             -1.5                 145.0
# 27     JNICASIO-R    956            4.0             -1.5                 185.0
# 28      BNORRIS-R    958           -2.0              1.5                -103.0
# 29    BFINNEGAN-L    960            1.0             -1.5                 165.0
# ...           ...    ...            ...              ...                   ...
# 2432    JLESTER-L    954            1.0             -1.5                 135.0
# 2433    CKLUBER-R    956            6.0             -1.5                 180.0
# 2434   YDARVISH-R    958           -2.0             -1.5                 154.0
# 2435  KHENDRCKS-R    962            3.0             -1.5                 120.0
# 2436   ASANCHEZ-R    934            1.0             -1.5                -109.0
# 2437     TROARK-R    936            3.0              1.5                -141.0
# 2438     KMAEDA-R    902           -5.0             -1.5                 155.0
# 2439  MBUMGARNR-L    904            1.0             -1.5                 183.0
# 2440  CBUCHHOLZ-R    906           -1.0             -1.5                 144.0
# 2441   CKERSHAW-L    952            1.0             -1.5                -130.0
# 2442     MMOORE-L    954           -1.0              1.5                -160.0
# 2443  MSCHERZER-R    962           -1.0             -1.5                 165.0
# 2444    CKLUBER-R    902            2.0             -1.5                 150.0
# 2445    JLESTER-L    904            4.0             -1.5                -106.0
# 2446    JTOMLIN-R    906            1.0              1.5                -150.0
# 2447  KHENDRCKS-R    908           -1.0              1.5                -145.0
# 2448   MSTROMAN-R    952           -2.0             -1.5                 109.0
# 2449      RHILL-L    954            6.0             -1.5                 185.0
# 2450   ASANCHEZ-R    956            4.0             -1.5                 175.0
# 2451     JURIAS-L    902           -8.0             -1.5                 185.0
# 2452   MESTRADA-R    904           -3.0             -1.5                 109.0
# 2453     KMAEDA-R    906           -4.0              1.5                -110.0
# 2454  KHENDRCKS-R    910            5.0              1.5                -160.0
# 2455    CKLUBER-R    952            6.0             -1.5                 199.0
# 2456     TBAUER-R    954           -4.0              1.5                -113.0
# 2457  KHENDRCKS-R    902           -1.0             -1.5                -110.0
# 2458    JLACKEY-R    904           -5.0             -1.5                 178.0
# 2459    JLESTER-L    906            1.0             -1.5                -101.0
# 2460    JTOMLIN-R    952           -6.0              1.5                -131.0
# 2461    CKLUBER-R    902           -1.0              1.5                -162.0
#
# [2462 rows x 33 columns]
