# %%
import numpy as np
import pandas as pd
from datetime import date

# %%
df = pd.read_pickle('unix_dataset.pickle')

# %%
df
# Out:
#                date  gameno visitor v_team  v_team_run_total  \
# 0      1.270354e+09       0       V    NYY               7.0
# 1      1.270440e+09       1       V    PHI              11.0
# 2      1.270440e+09       2       V    MIA               1.0
# 3      1.270440e+09       3       V    STL              11.0
# 4      1.270440e+09       4       V    LAD               5.0
# 5      1.270440e+09       5       V    COL               5.0
# 6      1.270440e+09       6       V    CHC               5.0
# 7      1.270440e+09       7       V     SD               3.0
# 8      1.270440e+09       8       V     SF               5.0
# 9      1.270440e+09       9       V    CLE               0.0
# 10     1.270440e+09      10       V    TOR               4.0
# 11     1.270440e+09      11       V    DET               8.0
# 12     1.270440e+09      12       V    MIN               3.0
# 13     1.270440e+09      13       V    SEA               5.0
# 14     1.270526e+09      14       V     SF               3.0
# 15     1.270526e+09      15       V    COL               5.0
# 16     1.270526e+09      16       V     SD               6.0
# 17     1.270526e+09      17       V    BAL               3.0
# 18     1.270526e+09      18       V    NYY               6.0
# 19     1.270526e+09      19       V    MIN               5.0
# 20     1.270526e+09      20       V    SEA               1.0
# 21     1.270613e+09      21       V    COL               4.0
# 22     1.270613e+09      22       V     SF              10.0
# 23     1.270613e+09      23       V    LAD               3.0
# 24     1.270613e+09      24       V    PHI               8.0
# 25     1.270613e+09      25       V    CHC               2.0
# 26     1.270613e+09      26       V    STL               6.0
# 27     1.270613e+09      27       V    MIA               7.0
# 28     1.270613e+09      28       V     SD               3.0
# 29     1.270613e+09      29       V    NYY               3.0
# ...             ...     ...     ...    ...               ...
# 22296  1.554523e+09   22296       V    WAS               5.0
# 22297  1.554523e+09   22297       V    CIN               5.0
# 22298  1.554523e+09   22298       V     SD               6.0
# 22299  1.554523e+09   22299       V    CHC              14.0
# 22300  1.554523e+09   22300       V    MIA               4.0
# 22301  1.554523e+09   22301       V    LAD               7.0
# 22302  1.554523e+09   22302       V     KC               4.0
# 22303  1.554523e+09   22303       V    SEA               9.0
# 22304  1.554523e+09   22304       V    TEX               1.0
# 22305  1.554523e+09   22305       V    TOR               2.0
# 22306  1.554523e+09   22306       V    NYY               6.0
# 22307  1.554523e+09   22307       V    OAK               0.0
# 22308  1.554523e+09   22308       V    MIN               6.0
# 22309  1.554523e+09   22309       V     TB               4.0
# 22310  1.554523e+09   22310       V    BOS               4.0
# 22311  1.554610e+09   22311       V    WAS              12.0
# 22312  1.554610e+09   22312       V    MIA               3.0
# 22313  1.554610e+09   22313       V    CIN               5.0
# 22314  1.554610e+09   22314       V    CHC               2.0
# 22315  1.554610e+09   22315       V     SD               1.0
# 22316  1.554610e+09   22316       V    LAD              12.0
# 22317  1.554610e+09   22317       V    NYY              15.0
# 22318  1.554610e+09   22318       V    TOR               1.0
# 22319  1.554610e+09   22319       V     KC               1.0
# 22320  1.554610e+09   22320       V    OAK               8.0
# 22321  1.554610e+09   22321       V    SEA              12.0
# 22322  1.554610e+09   22322       V    TEX               2.0
# 22323  1.554610e+09   22323       V    MIN               1.0
# 22324  1.554610e+09   22324       V     TB               3.0
# 22325  1.554610e+09   22325       V    BOS               1.0
#
#        v_money_line_close  v_money_line_open  v_run_line_close  \
# 0                   107.0                104               NaN
# 1                  -200.0               -200               NaN
# 2                  -102.0                105               NaN
# 3                  -143.0               -155               NaN
# 4                  -126.0               -155               NaN
# 5                  -105.0                110               NaN
# 6                   110.0                115               NaN
# 7                   166.0                155               NaN
# 8                  -147.0               -130               NaN
# 9                   127.0                150               NaN
# 10                  135.0                120               NaN
# 11                  112.0                105               NaN
# 12                  113.0                120               NaN
# 13                 -152.0               -125               NaN
# 14                  114.0                130               NaN
# 15                  143.0                125               NaN
# 16                  127.0                150               NaN
# 17                  205.0                140               NaN
# 18                  119.0                120               NaN
# 19                  124.0                110               NaN
# 20                  110.0                135               NaN
# 21                 -114.0               -105               NaN
# 22                 -134.0               -130               NaN
# 23                 -170.0               -132               NaN
# 24                 -185.0               -157               NaN
# 25                  128.0                140               NaN
# 26                 -144.0               -125               NaN
# 27                 -132.0               -110               NaN
# 28                  116.0                111               NaN
# 29                  123.0                120               NaN
# ...                   ...                ...               ...
# 22296              -128.0               -110              -1.5
# 22297               101.0                115               1.5
# 22298               110.0                120               1.5
# 22299               119.0                100               1.5
# 22300               161.0                144               1.5
# 22301              -116.0               -145              -1.5
# 22302               112.0                105               1.5
# 22303              -105.0               -120              -1.5
# 22304               150.0                105               1.5
# 22305               177.0                148               1.5
# 22306              -180.0               -195              -1.5
# 22307               125.0                144               1.5
# 22308               138.0                136               1.5
# 22309              -132.0               -137              -1.5
# 22310              -132.0               -151              -1.5
# 22311              -128.0               -140              -1.5
# 22312               160.0                155               1.5
# 22313               140.0                130               1.5
# 22314              -104.0                105               1.5
# 22315               110.0                110               1.5
# 22316              -170.0               -140              -1.5
# 22317              -185.0               -175              -1.5
# 22318               150.0                130               1.5
# 22319              -106.0               -105              -1.5
# 22320               165.0                140               1.5
# 22321               106.0               -110               1.5
# 22322               107.0                115               1.5
# 22323               124.0                110               1.5
# 22324              -115.0               -130              -1.5
# 22325              -106.0               -115              -1.5
#
#        v_run_line_odds_close      v_pitcher  ...  h_run_dif_game  \
# 0                        NaN    CSABATHIA-L  ...             2.0
# 1                        NaN    RHALLADAY-R  ...           -10.0
# 2                        NaN     JJOHNSON-R  ...             6.0
# 3                        NaN    CARPENTER-R  ...            -5.0
# 4                        NaN     VPADILLA-R  ...             6.0
# 5                        NaN     UJIMENEZ-R  ...            -2.0
# 6                        NaN    CZAMBRANO-R  ...            11.0
# 7                        NaN     JGARLAND-R  ...             3.0
# 8                        NaN    TLINCECUM-R  ...            -3.0
# 9                        NaN    WESTBROOK-R  ...             6.0
# 10                       NaN      SMARCUM-R  ...             1.0
# 11                       NaN    VERLANDER-R  ...            -4.0
# 12                       NaN       SBAKER-R  ...             3.0
# 13                       NaN    FHERNANDZ-R  ...            -2.0
# 14                       NaN        BZITO-L  ...            -3.0
# 15                       NaN       GSMITH-L  ...             2.0
# 16                       NaN       CYOUNG-R  ...            -3.0
# 17                       NaN    KMILLWOOD-R  ...             1.0
# 18                       NaN     ABURNETT-R  ...            -2.0
# 19                       NaN    NBLACKBUR-R  ...            -2.0
# 20                       NaN       ISNELL-R  ...             0.0
# 21                       NaN        ACOOK-R  ...             1.0
# 22                       NaN        MCAIN-R  ...            -6.0
# 23                       NaN     CKERSHAW-L  ...             1.0
# 24                       NaN      CHAMELS-L  ...            -4.0
# 25                       NaN    RDEMPSTER-R  ...             1.0
# 26                       NaN   WAINWRIGHT-R  ...            -3.0
# 27                       NaN     RNOLASCO-R  ...            -1.0
# 28                       NaN     KCORREIA-R  ...             2.0
# 29                       NaN    APETTITTE-L  ...            -2.0
# ...                      ...            ...  ...             ...
# 22296                  125.0      PCORBIN-L  ...             1.0
# 22297                 -205.0       TROARK-R  ...             1.0
# 22298                 -205.0     CPADDACK-R  ...            -2.0
# 22299                 -180.0      CHAMELS-L  ...            -6.0
# 22300                 -130.0   SALCANTARA-R  ...            -2.0
# 22301                  128.0     WBUEHLER-R  ...            -5.0
# 22302                 -185.0       JLOPEZ-R  ...             3.0
# 22303                  144.0       MLEAKE-R  ...            -7.0
# 22304                 -150.0       DSMYLY-L  ...             4.0
# 22305                 -114.0     TPANNONE-L  ...             5.0
# 22306                 -125.0        JHAPP-L  ...            -2.0
# 22307                 -154.0      ABROOKS-R  ...             6.0
# 22308                 -156.0      MPINEDA-R  ...            -4.0
# 22309                  125.0      RSTANEK-R  ...             2.0
# 22310                  119.0       DPRICE-L  ...             1.0
# 22311                  125.0    MSCHERZER-R  ...            -3.0
# 22312                 -135.0       CSMITH-L  ...             1.0
# 22313                 -166.0  ADESCLAFANI-R  ...             2.0
# 22314                 -210.0   KHENDRICKS-R  ...             2.0
# 22315                 -197.0      MSTRAHM-L  ...             3.0
# 22316                 -122.0       JURIAS-L  ...            -6.0
# 22317                 -119.0      DGERMAN-R  ...           -12.0
# 22318                 -147.0     MSTROMAN-R  ...             2.0
# 22319                  141.0      BKELLER-R  ...             2.0
# 22320                 -125.0       MFIERS-R  ...             1.0
# 22321                 -178.0     WLEBLANC-L  ...            -7.0
# 22322                 -180.0      SMILLER-R  ...             5.0
# 22323                 -180.0     JBERRIOS-R  ...             1.0
# 22324                  148.0    YCHIRINOS-R  ...            -3.0
# 22325                  130.0      Undecided  ...            -1.0
#
#        total_runs_game over_line_close over_line_open  over_odds_close  \
# 0                 16.0             9.0            9.0             -105
# 1                 12.0             7.5            7.5             -125
# 2                  8.0             7.0            7.0             -130
# 3                 17.0             7.5            7.5             -105
# 4                 16.0             8.5            8.5             -120
# 5                  8.0             7.5            7.5              105
# 6                 21.0             8.5            8.5              100
# 7                  9.0             8.0            8.0             -120
# 8                  7.0             7.0            7.5             -110
# 9                  6.0             9.0            9.0             -105
# 10                 9.0             9.0            9.5             -120
# 11                12.0             7.0            7.0             -105
# 12                 9.0             8.5            8.5             -130
# 13                 8.0             7.0            7.0             -115
# 14                 3.0             8.0            8.0             -105
# 15                12.0             9.0            8.5             -105
# 16                 9.0             9.5            9.0              100
# 17                 7.0             9.0            8.5             -115
# 18                10.0             9.5            9.5             -105
# 19                 8.0            10.0            9.0             -115
# 20                 2.0             8.5            8.5              105
# 21                 9.0             9.0            9.0              100
# 22                14.0             7.5            7.5              105
# 23                 7.0             8.0            8.0             -120
# 24                12.0             9.0            9.0             -120
# 25                 5.0             8.0            8.5             -115
# 26                 9.0             8.0            8.0             -130
# 27                13.0             8.5            8.5             -105
# 28                 8.0             9.5            9.5             -105
# 29                 4.0            10.0           10.0             -105
# ...                ...             ...            ...              ...
# 22296             11.0             7.0            7.0             -110
# 22297             11.0             8.0            7.0             -105
# 22298             10.0             7.5            7.5             -105
# 22299             22.0             8.5            8.5             -105
# 22300              6.0             8.5            8.0             -120
# 22301              9.0           100.0         -110.0             -120
# 22302             11.0             9.0            8.5             -105
# 22303             11.0             9.0            8.5             -105
# 22304              6.0             8.5            8.5             -110
# 22305              9.0             8.0            7.0              100
# 22306             10.0             8.5            8.5             -110
# 22307              6.0             9.5            8.5              100
# 22308              8.0             8.5            8.0              100
# 22309             10.0             7.5            7.0             -105
# 22310              9.0             9.0            9.0              100
# 22311             21.0             6.5            6.5              100
# 22312              7.0             8.5            8.5              100
# 22313             12.0             7.5            7.5             -115
# 22314              6.0             9.0            9.0             -110
# 22315              5.0             9.0            8.5             -110
# 22316             18.0          -120.0         -110.0              100
# 22317             18.0             9.0            9.0             -110
# 22318              4.0             7.5            7.0             -120
# 22319              4.0             9.0            8.5              100
# 22320             17.0             9.0            9.0              105
# 22321             17.0             9.0            9.0             -120
# 22322              9.0             9.5            9.0              100
# 22323              3.0             8.5            8.5              100
# 22324              3.0             7.0            7.5             -120
# 22325              1.0             9.5            9.5             -105
#
#        over_odds_open  under_line_close  under_line_open  under_odds_close  \
# 0                -116               9.0              9.0              -115
# 1                 100               7.5              7.5               105
# 2                -125               7.0              7.0               110
# 3                -105               7.5              7.5              -115
# 4                -110               8.5              8.5               100
# 5                -105               7.5              7.5              -125
# 6                -110               8.5              8.5              -120
# 7                -110               8.0              8.0               100
# 8                 105               7.0              7.5              -110
# 9                -105               9.0              9.0              -115
# 10               -105               9.0              9.5               100
# 11               -105               7.0              7.0              -115
# 12               -120               8.5              8.5               110
# 13               -115               7.0              7.0              -105
# 14                100               8.0              8.0              -115
# 15               -110               9.0              8.5              -115
# 16               -110               9.5              9.0              -120
# 17               -110               9.0              8.5              -105
# 18               -105               9.5              9.5              -115
# 19               -120              10.0              9.0              -105
# 20                100               8.5              8.5              -125
# 21               -105               9.0              9.0              -120
# 22               -105               7.5              7.5              -125
# 23               -110               8.0              8.0               100
# 24               -105               9.0              9.0               100
# 25               -110               8.0              8.5              -105
# 26               -110               8.0              8.0               110
# 27               -110               8.5              8.5              -115
# 28               -115               9.5              9.5              -115
# 29               -120              10.0             10.0              -115
# ...               ...               ...              ...               ...
# 22296            -115               7.0              7.0              -110
# 22297            -115               8.0              7.0              -115
# 22298            -115               7.5              7.5              -115
# 22299            -120               8.5              8.5              -115
# 22300            -120               8.5              8.0               100
# 22301            -110             100.0           -110.0               100
# 22302            -120               9.0              8.5              -115
# 22303            -115               9.0              8.5              -115
# 22304            -119               8.5              8.5              -110
# 22305            -115               8.0              7.0              -120
# 22306            -101               8.5              8.5              -110
# 22307            -101               9.5              8.5              -120
# 22308            -102               8.5              8.0              -120
# 22309            -110               7.5              7.0              -115
# 22310            -102               9.0              9.0              -120
# 22311            -110               6.5              6.5              -120
# 22312            -105               8.5              8.5              -120
# 22313            -110               7.5              7.5              -105
# 22314            -105               9.0              9.0              -110
# 22315             100               9.0              8.5              -110
# 22316            -110            -120.0           -110.0              -120
# 22317             100               9.0              9.0              -110
# 22318            -120               7.5              7.0               100
# 22319            -105               9.0              8.5              -120
# 22320             100               9.0              9.0              -125
# 22321             100               9.0              9.0               100
# 22322            -110               9.5              9.0              -120
# 22323             100               8.5              8.5              -120
# 22324            -110               7.0              7.5               100
# 22325            -110               9.5              9.5              -115
#
#       under_odds_open
# 0                -104
# 1                -120
# 2                 105
# 3                -115
# 4                -110
# 5                -115
# 6                -110
# 7                -110
# 8                -125
# 9                -115
# 10               -115
# 11               -115
# 12                100
# 13               -105
# 14               -120
# 15               -110
# 16               -110
# 17               -110
# 18               -115
# 19                100
# 20               -120
# 21               -115
# 22               -115
# 23               -110
# 24               -115
# 25               -110
# 26               -110
# 27               -110
# 28               -105
# 29                100
# ...               ...
# 22296            -105
# 22297            -105
# 22298            -105
# 22299             100
# 22300             100
# 22301            -110
# 22302             100
# 22303            -105
# 22304            -101
# 22305            -105
# 22306            -119
# 22307            -119
# 22308            -118
# 22309            -110
# 22310            -118
# 22311            -110
# 22312            -115
# 22313            -110
# 22314            -115
# 22315            -120
# 22316            -110
# 22317            -120
# 22318             100
# 22319            -115
# 22320            -120
# 22321            -120
# 22322            -110
# 22323            -120
# 22324            -110
# 22325            -110
#
# [22326 rows x 31 columns]

# %%
# data.drop(['Unnamed: 0'], axis=1, inplace=True)
df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)

# %%
df.info()

# %%
start_date=date(2018,1,1)
end_date=date(2019,12,31)
df['date'] = pd.to_datetime(df['date'])
df2 = df[df['date'].isin(pd.date_range(start_date,end_date))]
