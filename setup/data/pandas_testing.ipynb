# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/Users/james/Desktop/Byte/baseball_project/setup/data/baseball.csv', low_memory=False)

# %%
# data.drop(['Unnamed: 0'], axis=1, inplace=True)
data['date'] = pd.to_datetime(data['date'], infer_datetime_format=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44642 entries, 0 to 44641
# Data columns (total 17 columns):
# date                     44642 non-null datetime64[ns]
# gameno                   44642 non-null int64
# team                     44642 non-null object
# visitor_home             44642 non-null object
# team_run_total           44640 non-null float64
# total_runs_game          44640 non-null float64
# money_line_close         44642 non-null float64
# money_line_open          44642 non-null int64
# over_under_line_close    44642 non-null float64
# over_under_line_open     44642 non-null float64
# over_under_odds_close    44642 non-null int64
# over_under_odds_open     44642 non-null int64
# pitcher                  44599 non-null object
# rot                      44642 non-null int64
# run_dif_game             44640 non-null float64
# run_line_close           24912 non-null float64
# run_line_odds_close      24912 non-null float64
# dtypes: datetime64[ns](1), float64(8), int64(5), object(3)
# memory usage: 5.8+ MB

# %%
data
# Out:
#        Unnamed: 0        date  gameno team visitor_home  team_run_total  \
# 0               0  2010-04-04       0  NYY            V             7.0
# 1               1  2010-04-04       0  BOS            H             9.0
# 2               2  2010-04-05       1  PHI            V            11.0
# 3               3  2010-04-05       1  WAS            H             1.0
# 4               4  2010-04-05       2  MIA            V             1.0
# 5               5  2010-04-05       2  NYM            H             7.0
# 6               6  2010-04-05       3  STL            V            11.0
# 7               7  2010-04-05       3  CIN            H             6.0
# 8               8  2010-04-05       4  LAD            V             5.0
# 9               9  2010-04-05       4  PIT            H            11.0
# 10             10  2010-04-05       5  COL            V             5.0
# 11             11  2010-04-05       5  MIL            H             3.0
# 12             12  2010-04-05       6  CHC            V             5.0
# 13             13  2010-04-05       6  ATL            H            16.0
# 14             14  2010-04-05       7   SD            V             3.0
# 15             15  2010-04-05       7  ARI            H             6.0
# 16             16  2010-04-05       8   SF            V             5.0
# 17             17  2010-04-05       8  HOU            H             2.0
# 18             18  2010-04-05       9  CLE            V             0.0
# 19             19  2010-04-05       9  CWS            H             6.0
# 20             20  2010-04-05      10  TOR            V             4.0
# 21             21  2010-04-05      10  TEX            H             5.0
# 22             22  2010-04-05      11  DET            V             8.0
# 23             23  2010-04-05      11   KC            H             4.0
# 24             24  2010-04-05      12  MIN            V             3.0
# 25             25  2010-04-05      12  LAA            H             6.0
# 26             26  2010-04-05      13  SEA            V             5.0
# 27             27  2010-04-05      13  OAK            H             3.0
# 28             28  2010-04-06      14   SF            V             3.0
# 29             29  2010-04-06      14  HOU            H             0.0
# ...           ...         ...     ...  ...          ...             ...
# 44612         254  2019-04-06   22303  BOS            V             4.0
# 44613         255  2019-04-06   22303  ARI            H             5.0
# 44614         256  2019-04-07   22304  WAS            V            12.0
# 44615         257  2019-04-07   22304  NYM            H             9.0
# 44616         258  2019-04-07   22305  MIA            V             3.0
# 44617         259  2019-04-07   22305  ATL            H             4.0
# 44618         260  2019-04-07   22306  CIN            V             5.0
# 44619         261  2019-04-07   22306  PIT            H             7.0
# 44620         262  2019-04-07   22307  CHC            V             2.0
# 44621         263  2019-04-07   22307  MIL            H             4.0
# 44622         264  2019-04-07   22308   SD            V             1.0
# 44623         265  2019-04-07   22308  STL            H             4.0
# 44624         268  2019-04-07   22310  NYY            V            15.0
# 44625         269  2019-04-07   22310  BAL            H             3.0
# 44626         270  2019-04-07   22311  TOR            V             1.0
# 44627         271  2019-04-07   22311  CLE            H             3.0
# 44628         272  2019-04-07   22312   KC            V             1.0
# 44629         273  2019-04-07   22312  DET            H             3.0
# 44630         274  2019-04-07   22313  OAK            V             8.0
# 44631         275  2019-04-07   22313  HOU            H             9.0
# 44632         276  2019-04-07   22314  SEA            V            12.0
# 44633         277  2019-04-07   22314  CWS            H             5.0
# 44634         278  2019-04-07   22315  TEX            V             2.0
# 44635         279  2019-04-07   22315  LAA            H             7.0
# 44636         280  2019-04-07   22316  MIN            V             1.0
# 44637         281  2019-04-07   22316  PHI            H             2.0
# 44638         282  2019-04-07   22317   TB            V             3.0
# 44639         283  2019-04-07   22317   SF            H             0.0
# 44640         284  2019-04-07   22318  BOS            V             1.0
# 44641         285  2019-04-07   22318  ARI            H             0.0
#
#        total_runs_game  money_line_close  money_line_open  \
# 0                 16.0             107.0              104
# 1                 16.0            -117.0             -114
# 2                 12.0            -200.0             -200
# 3                 12.0             175.0              175
# 4                  8.0            -102.0              105
# 5                  8.0            -108.0             -115
# 6                 17.0            -143.0             -155
# 7                 17.0             128.0              140
# 8                 16.0            -126.0             -155
# 9                 16.0             111.0              140
# 10                 8.0            -105.0              110
# 11                 8.0            -105.0             -125
# 12                21.0             110.0              115
# 13                21.0            -125.0             -130
# 14                 9.0             166.0              155
# 15                 9.0            -186.0             -175
# 16                 7.0            -147.0             -130
# 17                 7.0             132.0              115
# 18                 6.0             127.0              150
# 19                 6.0            -142.0             -170
# 20                 9.0             135.0              120
# 21                 9.0            -150.0             -135
# 22                12.0             112.0              105
# 23                12.0            -122.0             -115
# 24                 9.0             113.0              120
# 25                 9.0            -128.0             -135
# 26                 8.0            -152.0             -125
# 27                 8.0             137.0              110
# 28                 3.0             114.0              130
# 29                 3.0            -124.0             -145
# ...                ...               ...              ...
# 44612              9.0            -132.0             -151
# 44613              9.0             122.0              131
# 44614             21.0            -128.0             -140
# 44615             21.0             118.0              120
# 44616              7.0             160.0              155
# 44617              7.0            -170.0             -180
# 44618             12.0             140.0              130
# 44619             12.0            -150.0             -150
# 44620              6.0            -104.0              105
# 44621              6.0            -106.0             -125
# 44622              5.0             110.0              110
# 44623              5.0            -120.0             -130
# 44624             18.0            -185.0             -175
# 44625             18.0             170.0              151
# 44626              4.0             150.0              130
# 44627              4.0            -160.0             -150
# 44628              4.0            -106.0             -105
# 44629              4.0            -104.0             -115
# 44630             17.0             165.0              140
# 44631             17.0            -180.0             -160
# 44632             17.0             106.0             -110
# 44633             17.0            -116.0             -110
# 44634              9.0             107.0              115
# 44635              9.0            -117.0             -135
# 44636              3.0             124.0              110
# 44637              3.0            -134.0             -130
# 44638              3.0            -115.0             -130
# 44639              3.0             105.0              110
# 44640              1.0            -106.0             -115
# 44641              1.0            -104.0             -105
#
#        over_under_line_close  over_under_line_open  over_under_odds_close  \
# 0                        9.0                   9.0                   -105
# 1                        9.0                   9.0                   -115
# 2                        7.5                   7.5                   -125
# 3                        7.5                   7.5                    105
# 4                        7.0                   7.0                   -130
# 5                        7.0                   7.0                    110
# 6                        7.5                   7.5                   -105
# 7                        7.5                   7.5                   -115
# 8                        8.5                   8.5                   -120
# 9                        8.5                   8.5                    100
# 10                       7.5                   7.5                    105
# 11                       7.5                   7.5                   -125
# 12                       8.5                   8.5                    100
# 13                       8.5                   8.5                   -120
# 14                       8.0                   8.0                   -120
# 15                       8.0                   8.0                    100
# 16                       7.0                   7.5                   -110
# 17                       7.0                   7.5                   -110
# 18                       9.0                   9.0                   -105
# 19                       9.0                   9.0                   -115
# 20                       9.0                   9.5                   -120
# 21                       9.0                   9.5                    100
# 22                       7.0                   7.0                   -105
# 23                       7.0                   7.0                   -115
# 24                       8.5                   8.5                   -130
# 25                       8.5                   8.5                    110
# 26                       7.0                   7.0                   -115
# 27                       7.0                   7.0                   -105
# 28                       8.0                   8.0                   -105
# 29                       8.0                   8.0                   -115
# ...                      ...                   ...                    ...
# 44612                    9.0                   9.0                    100
# 44613                    9.0                   9.0                   -120
# 44614                    6.5                   6.5                    100
# 44615                    6.5                   6.5                   -120
# 44616                    8.5                   8.5                    100
# 44617                    8.5                   8.5                   -120
# 44618                    7.5                   7.5                   -115
# 44619                    7.5                   7.5                   -105
# 44620                    9.0                   9.0                   -110
# 44621                    9.0                   9.0                   -110
# 44622                    9.0                   8.5                   -110
# 44623                    9.0                   8.5                   -110
# 44624                    9.0                   9.0                   -110
# 44625                    9.0                   9.0                   -110
# 44626                    7.5                   7.0                   -120
# 44627                    7.5                   7.0                    100
# 44628                    9.0                   8.5                    100
# 44629                    9.0                   8.5                   -120
# 44630                    9.0                   9.0                    105
# 44631                    9.0                   9.0                   -125
# 44632                    9.0                   9.0                   -120
# 44633                    9.0                   9.0                    100
# 44634                    9.5                   9.0                    100
# 44635                    9.5                   9.0                   -120
# 44636                    8.5                   8.5                    100
# 44637                    8.5                   8.5                   -120
# 44638                    7.0                   7.5                   -120
# 44639                    7.0                   7.5                    100
# 44640                    9.5                   9.5                   -105
# 44641                    9.5                   9.5                   -115
#
#        over_under_odds_open        pitcher  rot  run_dif_game  run_line_close  \
# 0                      -116    CSABATHIA-L  931          -2.0             NaN
# 1                      -104     JBECKETT-R  932           2.0             NaN
# 2                       100    RHALLADAY-R  901          10.0             NaN
# 3                      -120      JLANNAN-L  902         -10.0             NaN
# 4                      -125     JJOHNSON-R  903          -6.0             NaN
# 5                       105    JOSANTANA-L  904           6.0             NaN
# 6                      -105    CARPENTER-R  905           5.0             NaN
# 7                      -115      AHARANG-R  906          -5.0             NaN
# 8                      -110     VPADILLA-R  907          -6.0             NaN
# 9                      -110        ZDUKE-L  908           6.0             NaN
# 10                     -105     UJIMENEZ-R  909           2.0             NaN
# 11                     -115    YGALLARDO-R  910          -2.0             NaN
# 12                     -110    CZAMBRANO-R  911         -11.0             NaN
# 13                     -110        DLOWE-R  912          11.0             NaN
# 14                     -110     JGARLAND-R  913          -3.0             NaN
# 15                     -110       DHAREN-R  914           3.0             NaN
# 16                      105    TLINCECUM-R  915           3.0             NaN
# 17                     -125      ROSWALT-R  916          -3.0             NaN
# 18                     -105    WESTBROOK-R  917          -6.0             NaN
# 19                     -115     MBUEHRLE-L  918           6.0             NaN
# 20                     -105      SMARCUM-R  919          -1.0             NaN
# 21                     -115     SFELDMAN-R  920           1.0             NaN
# 22                     -105    VERLANDER-R  921           4.0             NaN
# 23                     -115     ZGREINKE-R  922          -4.0             NaN
# 24                     -120       SBAKER-R  923          -3.0             NaN
# 25                      100    JERWEAVER-R  924           3.0             NaN
# 26                     -115    FHERNANDZ-R  925           2.0             NaN
# 27                     -105      BSHEETS-R  926          -2.0             NaN
# 28                      100        BZITO-L  951           3.0             NaN
# 29                     -120    WRODRIGEZ-L  952          -3.0             NaN
# ...                     ...            ...  ...           ...             ...
# 44612                  -102       DPRICE-L  979          -1.0            -1.5
# 44613                  -118      LWEAVER-R  980           1.0             1.5
# 44614                  -110    MSCHERZER-R  901           3.0            -1.5
# 44615                  -110     ZWHEELER-R  902          -3.0             1.5
# 44616                  -105       CSMITH-L  903          -1.0             1.5
# 44617                  -115     SNEWCOMB-L  904           1.0            -1.5
# 44618                  -110  ADESCLAFANI-R  905          -2.0             1.5
# 44619                  -110      CARCHER-R  906           2.0            -1.5
# 44620                  -105   KHENDRICKS-R  907          -2.0             1.5
# 44621                  -115      ZDAVIES-R  908           2.0            -1.5
# 44622                   100      MSTRAHM-L  909          -3.0             1.5
# 44623                  -120  AWAINWRIGHT-R  910           3.0            -1.5
# 44624                   100      DGERMAN-R  913          12.0            -1.5
# 44625                  -120        DHESS-R  914         -12.0             1.5
# 44626                  -120     MSTROMAN-R  915          -2.0             1.5
# 44627                   100   MCLEVINGER-R  916           2.0            -1.5
# 44628                  -105      BKELLER-R  917          -2.0            -1.5
# 44629                  -115        TROSS-R  918           2.0             1.5
# 44630                   100       MFIERS-R  919          -1.0             1.5
# 44631                  -120     BPEACOCK-R  920           1.0            -1.5
# 44632                   100     WLEBLANC-L  921           7.0             1.5
# 44633                  -120        INOVA-R  922          -7.0            -1.5
# 44634                  -110      SMILLER-R  923          -5.0             1.5
# 44635                  -110    CSTRATTON-R  924           5.0            -1.5
# 44636                   100     JBERRIOS-R  925          -1.0             1.5
# 44637                  -120       ZEFLIN-R  926           1.0            -1.5
# 44638                  -110    YCHIRINOS-R  927           3.0            -1.5
# 44639                  -110    DPOMERANZ-L  928          -3.0             1.5
# 44640                  -110      Undecided  929           1.0            -1.5
# 44641                  -110       MKELLY-R  930          -1.0             1.5
#
#        run_line_odds_close
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# ...                    ...
# 44612                119.0
# 44613               -139.0
# 44614                125.0
# 44615               -145.0
# 44616               -135.0
# 44617                115.0
# 44618               -166.0
# 44619                145.0
# 44620               -210.0
# 44621                176.0
# 44622               -197.0
# 44623                168.0
# 44624               -119.0
# 44625               -101.0
# 44626               -147.0
# 44627                128.0
# 44628                141.0
# 44629               -161.0
# 44630               -125.0
# 44631                105.0
# 44632               -178.0
# 44633                153.0
# 44634               -180.0
# 44635                155.0
# 44636               -180.0
# 44637                155.0
# 44638                148.0
# 44639               -170.0
# 44640                130.0
# 44641               -150.0
#
# [44642 rows x 18 columns]

# %%
games = data.groupby(['gameno'])
for name, group in games:
