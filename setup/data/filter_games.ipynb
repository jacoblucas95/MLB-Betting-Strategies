# %%
import numpy as np
import pandas as pd
import datetime

# %%
df = pd.read_csv('baseball.csv', low_memory=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44642 entries, 0 to 44641
# Data columns (total 20 columns):
# date                     44642 non-null object
# gameno                   44642 non-null int64
# team                     44642 non-null object
# visitor_home             44642 non-null object
# team_run_total           44640 non-null float64
# total_runs_game          44640 non-null float64
# over_under_win           44642 non-null int64
# money_line_close         44642 non-null float64
# money_line_open          44642 non-null int64
# money_line_win           44642 non-null int64
# over_under_line_close    44642 non-null float64
# over_under_line_open     44642 non-null float64
# over_under_odds_close    44642 non-null int64
# over_under_odds_open     44642 non-null int64
# pitcher                  44599 non-null object
# rot                      44642 non-null int64
# run_dif_game             44640 non-null float64
# run_line_close           24912 non-null float64
# run_line_odds_close      24912 non-null float64
# run_line_win             24912 non-null float64
# dtypes: float64(9), int64(7), object(4)
# memory usage: 6.8+ MB

# %%
data.replace('NL','0', inplace=True)

# %%
over_count = 0
under_count = 0
push_count = 0
for i,g in data.groupby(['gameno']):
    o_u = g[::2]
    if pd.to_numeric(o_u.totalruns.all()) > o_u.close_ou:
        over_count += 1
    elif pd.to_numeric(o_u.totalruns.all()) < o_u.close_ou:
        under_count += 1
    else:
        push_count += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-82cf80521cad> in <module>
#       4 for i,g in data.groupby(['gameno']):
#       5     o_u = g[::2]
# ----> 6     if pd.to_numeric(o_u.totalruns.all()) > o_u.close_ou:
#       7         over_count += 1
#       8     elif pd.to_numeric(o_u.totalruns.all()) < o_u.close_ou:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'totalruns'

# %%
data.tail()
# Out:
#              date  gameno team visitor_home  team_run_total  total_runs_game  \
# 44637  2019-04-07   22316  PHI            H             2.0              3.0
# 44638  2019-04-07   22317   TB            V             3.0              3.0
# 44639  2019-04-07   22317   SF            H             0.0              3.0
# 44640  2019-04-07   22318  BOS            V             1.0              1.0
# 44641  2019-04-07   22318  ARI            H             0.0              1.0
#
#        over_under_win  money_line_close  money_line_open  money_line_win  \
# 44637               1            -134.0             -130               1
# 44638              -1            -115.0             -130               1
# 44639               1             105.0              110              -1
# 44640              -1            -106.0             -115               1
# 44641               1            -104.0             -105              -1
#
#        over_under_line_close  over_under_line_open  over_under_odds_close  \
# 44637                    8.5                   8.5                   -120
# 44638                    7.0                   7.5                   -120
# 44639                    7.0                   7.5                    100
# 44640                    9.5                   9.5                   -105
# 44641                    9.5                   9.5                   -115
#
#        over_under_odds_open      pitcher  rot  run_dif_game  run_line_close  \
# 44637                  -120     ZEFLIN-R  926           1.0            -1.5
# 44638                  -110  YCHIRINOS-R  927           3.0            -1.5
# 44639                  -110  DPOMERANZ-L  928          -3.0             1.5
# 44640                  -110    Undecided  929           1.0            -1.5
# 44641                  -110     MKELLY-R  930          -1.0             1.5
#
#        run_line_odds_close  run_line_win
# 44637                155.0          -1.0
# 44638                148.0           1.0
# 44639               -170.0          -1.0
# 44640                130.0          -1.0
# 44641               -150.0           1.0

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
date_range = data[data['date'].isin(pd.date_range('2010-04-05', '2010-04-07'))]

# %%
date_range
# Out:
#          date  gameno team visitor_home  team_run_total  total_runs_game  \
# 2  2010-04-05       1  PHI            V            11.0             12.0
#     over_under_win  money_line_close  money_line_open  money_line_win  \
# 2                1            -200.0             -200               1
# 3               -1             175.0              175              -1
# 4                1            -102.0              105              -1
# 5               -1            -108.0             -115               1
# 6                1            -143.0             -155               1
# 7               -1             128.0              140              -1
# 8                1            -126.0             -155              -1
# 9               -1             111.0              140               1
# 10               1            -105.0              110               1
# 11              -1            -105.0             -125              -1
# 12               1             110.0              115              -1
# 13              -1            -125.0             -130               1
# 14               1             166.0              155              -1
# 15              -1            -186.0             -175               1
# 16               0            -147.0             -130               1
# 17               0             132.0              115              -1
# 18              -1             127.0              150              -1
# 19               1            -142.0             -170               1
# 20               0             135.0              120              -1
# 21               0            -150.0             -135               1
# 22               1             112.0              105               1
# 23              -1            -122.0             -115              -1
# 24               1             113.0              120              -1
# 25              -1            -128.0             -135               1
# 26               1            -152.0             -125               1
# 27              -1             137.0              110              -1
# 28              -1             114.0              130               1
# 29               1            -124.0             -145              -1
# 30               1             143.0              125              -1
# 31              -1            -158.0             -140               1
# ..             ...               ...              ...             ...
# 42               0            -114.0             -105              -1
# 43               0             104.0             -105               1
# 44               1            -134.0             -130               1
# 45              -1             119.0              115              -1
# 46              -1            -170.0             -132              -1
# 47               1             150.0              117               1
# 48               1            -185.0             -157               1
# 49              -1             165.0              142              -1
# 50              -1             128.0              140              -1
# 51               1            -143.0             -160               1
# 52               1            -144.0             -125               1
# 53              -1             129.0              110              -1
# 54               1            -132.0             -110               1
# 55              -1             117.0              100              -1
# 56              -1             116.0              111              -1
# 57               1            -131.0             -121               1
# 58              -1             123.0              120               1
# 59               1            -138.0             -135              -1
# 60              -1             195.0              165              -1
# 61               1            -220.0             -185               1
# 62               1             156.0              143               1
# 63              -1            -176.0             -158              -1
# 64               0             135.0              145               1
# 65               0            -150.0             -165              -1
# 66              -1            -127.0             -118              -1
# 67               1             112.0              108               1
# 68              -1             120.0              115               1
# 69               1            -135.0             -130              -1
# 70               1             112.0             -105              -1
# 71              -1            -122.0             -105               1
#
#     over_under_line_close  over_under_line_open  over_under_odds_close  \
# 2                     7.5                   7.5                   -125
# 3                     7.5                   7.5                    105
# 4                     7.0                   7.0                   -130
# 5                     7.0                   7.0                    110
# 6                     7.5                   7.5                   -105
# 7                     7.5                   7.5                   -115
# 8                     8.5                   8.5                   -120
# 9                     8.5                   8.5                    100
# 10                    7.5                   7.5                    105
# 11                    7.5                   7.5                   -125
# 12                    8.5                   8.5                    100
# 13                    8.5                   8.5                   -120
# 14                    8.0                   8.0                   -120
# 15                    8.0                   8.0                    100
# 16                    7.0                   7.5                   -110
# 17                    7.0                   7.5                   -110
# 18                    9.0                   9.0                   -105
# 19                    9.0                   9.0                   -115
# 20                    9.0                   9.5                   -120
# 21                    9.0                   9.5                    100
# 22                    7.0                   7.0                   -105
# 23                    7.0                   7.0                   -115
# 24                    8.5                   8.5                   -130
# 25                    8.5                   8.5                    110
# 26                    7.0                   7.0                   -115
# 27                    7.0                   7.0                   -105
# 28                    8.0                   8.0                   -105
# 29                    8.0                   8.0                   -115
# 30                    9.0                   8.5                   -105
# 31                    9.0                   8.5                   -115
# ..                    ...                   ...                    ...
# 42                    9.0                   9.0                    100
# 43                    9.0                   9.0                   -120
# 44                    7.5                   7.5                    105
# 45                    7.5                   7.5                   -125
# 46                    8.0                   8.0                   -120
# 47                    8.0                   8.0                    100
# 48                    9.0                   9.0                   -120
# 49                    9.0                   9.0                    100
# 50                    8.0                   8.5                   -115
# 51                    8.0                   8.5                   -105
# 52                    8.0                   8.0                   -130
# 53                    8.0                   8.0                    110
# 54                    8.5                   8.5                   -105
# 55                    8.5                   8.5                   -115
# 56                    9.5                   9.5                   -105
# 57                    9.5                   9.5                   -115
# 58                   10.0                  10.0                   -105
# 59                   10.0                  10.0                   -115
# 60                    9.0                   9.0                   -125
# 61                    9.0                   9.0                    105
# 62                    9.0                   9.0                   -110
# 63                    9.0                   9.0                   -110
# 64                    8.0                   8.5                    105
# 65                    8.0                   8.5                   -125
# 66                    8.5                   9.0                   -105
# 67                    8.5                   9.0                   -115
# 68                    9.5                   9.5                   -115
# 69                    9.5                   9.5                   -105
# 70                    7.5                   8.0                    100
# 71                    7.5                   8.0                   -120
#
#     over_under_odds_open       pitcher  rot  run_dif_game  run_line_close  \
# 2                    100   RHALLADAY-R  901          10.0             NaN
# 3                   -120     JLANNAN-L  902         -10.0             NaN
# 4                   -125    JJOHNSON-R  903          -6.0             NaN
# 5                    105   JOSANTANA-L  904           6.0             NaN
# 6                   -105   CARPENTER-R  905           5.0             NaN
# 7                   -115     AHARANG-R  906          -5.0             NaN
# 8                   -110    VPADILLA-R  907          -6.0             NaN
# 9                   -110       ZDUKE-L  908           6.0             NaN
# 10                  -105    UJIMENEZ-R  909           2.0             NaN
# 11                  -115   YGALLARDO-R  910          -2.0             NaN
# 12                  -110   CZAMBRANO-R  911         -11.0             NaN
# 13                  -110       DLOWE-R  912          11.0             NaN
# 14                  -110    JGARLAND-R  913          -3.0             NaN
# 15                  -110      DHAREN-R  914           3.0             NaN
# 16                   105   TLINCECUM-R  915           3.0             NaN
# 17                  -125     ROSWALT-R  916          -3.0             NaN
# 18                  -105   WESTBROOK-R  917          -6.0             NaN
# 19                  -115    MBUEHRLE-L  918           6.0             NaN
# 20                  -105     SMARCUM-R  919          -1.0             NaN
# 21                  -115    SFELDMAN-R  920           1.0             NaN
# 22                  -105   VERLANDER-R  921           4.0             NaN
# 23                  -115    ZGREINKE-R  922          -4.0             NaN
# 24                  -120      SBAKER-R  923          -3.0             NaN
# 25                   100   JERWEAVER-R  924           3.0             NaN
# 26                  -115   FHERNANDZ-R  925           2.0             NaN
# 27                  -105     BSHEETS-R  926          -2.0             NaN
# 28                   100       BZITO-L  951           3.0             NaN
# 29                  -120   WRODRIGEZ-L  952          -3.0             NaN
# 30                  -110      GSMITH-L  953          -2.0             NaN
# 31                  -110       RWOLF-L  954           2.0             NaN
# ..                   ...           ...  ...           ...             ...
# 42                  -105       ACOOK-R  901          -1.0             NaN
# 43                  -115      DDAVIS-L  902           1.0             NaN
# 44                  -105       MCAIN-R  903           6.0             NaN
# 45                  -115      BMYERS-R  904          -6.0             NaN
# 46                  -110    CKERSHAW-L  905          -1.0             NaN
# 47                  -110   ROHLENDOR-R  906           1.0             NaN
# 48                  -105     CHAMELS-L  907           4.0             NaN
# 49                  -115    JMARQUIS-R  908          -4.0             NaN
# 50                  -110   RDEMPSTER-R  909          -1.0             NaN
# 51                  -110   JJURRJENS-R  910           1.0             NaN
# 52                  -110  WAINWRIGHT-R  911           3.0             NaN
# 53                  -110      JCUETO-R  912          -3.0             NaN
# 54                  -110    RNOLASCO-R  913           1.0             NaN
# 55                  -110      JMAINE-R  914          -1.0             NaN
# 56                  -115    KCORREIA-R  915          -2.0             NaN
# 57                  -105    IKENNEDY-R  916           2.0             NaN
# 58                  -120   APETTITTE-L  917           2.0             NaN
# 59                   100     JLACKEY-R  918          -2.0             NaN
# 60                  -115    JGUTHRIE-R  919          -1.0             NaN
# 61                  -105      MGARZA-R  920           1.0             NaN
# 62                  -120     BTALLET-L  921           3.0             NaN
# 63                   100     RHARDEN-R  922          -3.0             NaN
# 64                  -115    FCARMONA-R  923           2.0             NaN
# 65                  -105      JPEAVY-R  924          -2.0             NaN
# 66                  -105   MSCHERZER-R  925          -1.0             NaN
# 67                  -115   LHOCHEVAR-R  926           1.0             NaN
# 68                  -115     CPAVANO-R  927           2.0             NaN
# 69                  -105    ESANTANA-R  928          -2.0             NaN
# 70                  -105  RWLND-SMTH-L  929          -1.0             NaN
# 71                  -115  DUCHSHERER-R  930           1.0             NaN
#
#     run_line_odds_close  run_line_win
# 2                   NaN           NaN
# 3                   NaN           NaN
# 4                   NaN           NaN
# 5                   NaN           NaN
# 6                   NaN           NaN
# 7                   NaN           NaN
# 8                   NaN           NaN
# 9                   NaN           NaN
# 10                  NaN           NaN
# 11                  NaN           NaN
# 12                  NaN           NaN
# 13                  NaN           NaN
# 14                  NaN           NaN
# 15                  NaN           NaN
# 16                  NaN           NaN
# 17                  NaN           NaN
# 18                  NaN           NaN
# 19                  NaN           NaN
# 20                  NaN           NaN
# 21                  NaN           NaN
# 22                  NaN           NaN
# 23                  NaN           NaN
# 24                  NaN           NaN
# 25                  NaN           NaN
# 26                  NaN           NaN
# 27                  NaN           NaN
# 28                  NaN           NaN
# 29                  NaN           NaN
# 30                  NaN           NaN
# 31                  NaN           NaN
# ..                  ...           ...
# 42                  NaN           NaN
# 43                  NaN           NaN
# 44                  NaN           NaN
# 45                  NaN           NaN
# 46                  NaN           NaN
# 47                  NaN           NaN
# 48                  NaN           NaN
# 49                  NaN           NaN
# 50                  NaN           NaN
# 51                  NaN           NaN
# 52                  NaN           NaN
# 53                  NaN           NaN
# 54                  NaN           NaN
# 55                  NaN           NaN
# 56                  NaN           NaN
# 57                  NaN           NaN
# 58                  NaN           NaN
# 59                  NaN           NaN
# 60                  NaN           NaN
# 61                  NaN           NaN
# 62                  NaN           NaN
# 63                  NaN           NaN
# 64                  NaN           NaN
# 65                  NaN           NaN
# 66                  NaN           NaN
# 67                  NaN           NaN
# 68                  NaN           NaN
# 69                  NaN           NaN
# 70                  NaN           NaN
# 71                  NaN           NaN
#
# [70 rows x 20 columns]

# %%
df.loc[(df['money_line_close'] > 0) & (df['visitor_home'] == 'H')]
# Out:
#              date  gameno team visitor_home  team_run_total  total_runs_game  \
# 3      2010-04-05       1  WAS            H             1.0             12.0
# 7      2010-04-05       3  CIN            H             6.0             17.0
# 44639  2019-04-07   22317   SF            H             0.0              3.0
#
#        over_under_win  money_line_close  money_line_open  money_line_win  \
# 3                  -1             175.0              175              -1
# 7                  -1             128.0              140              -1
# 9                  -1             111.0              140               1
# 17                  0             132.0              115              -1
# 27                 -1             137.0              110              -1
# 43                  0             104.0             -105               1
# 45                 -1             119.0              115              -1
# 47                  1             150.0              117               1
# 49                 -1             165.0              142              -1
# 53                 -1             129.0              110              -1
# 55                 -1             117.0              100              -1
# 67                  1             112.0              108               1
# 73                 -1             129.0             -144              -1
# 77                 -1             138.0              135               1
# 103                -1             110.0             -101              -1
# 105                 1             144.0              137              -1
# 115                -1             105.0             -104               1
# 119                 1             136.0              134               1
# 125                 1             100.0             -120              -1
# 131                -1             140.0              120              -1
# 139                 0             107.0              110              -1
# 143                 1             122.0              103              -1
# 145                -1             130.0              127              -1
# 147                 1             126.0              120              -1
# 151                -1             100.0              110              -1
# 159                 1             103.0             -120               1
# 161                 1             195.0              160              -1
# 169                -1             125.0              115               1
# 175                -1             105.0             -125              -1
# 179                -1             147.0              110              -1
# ...               ...               ...              ...             ...
# 44459               1             103.0             -101               1
# 44461              -1             100.0             -105               1
# 44467              -1             126.0              130               1
# 44469              -1             120.0              135               1
# 44477              -1             115.0              130              -1
# 44489               1             155.0              144              -1
# 44491               1             130.0              120               1
# 44497               1             100.0              101              -1
# 44501              -1             126.0              106              -1
# 44511              -1             200.0              184               1
# 44513              -1             135.0              121              -1
# 44515               1             160.0              148               1
# 44523              -1             125.0              110               1
# 44527              -1             190.0              180              -1
# 44537              -1             120.0              125              -1
# 44543               1             190.0              144               1
# 44545              -1             130.0              110              -1
# 44551               1             100.0             -125               1
# 44557              -1             195.0              170              -1
# 44559              -1             108.0              100               1
# 44577               0             103.0              115              -1
# 44581              -1             117.0              110               1
# 44583              -1             115.0              110               1
# 44587              -1             118.0             -110               1
# 44605              -1             165.0              166              -1
# 44611              -1             122.0              124               1
# 44613               0             122.0              131               1
# 44615              -1             118.0              120              -1
# 44625              -1             170.0              151              -1
# 44639               1             105.0              110              -1
#
#        over_under_line_close  over_under_line_open  over_under_odds_close  \
# 3                        7.5                   7.5                    105
# 7                        7.5                   7.5                   -115
# 9                        8.5                   8.5                    100
# 17                       7.0                   7.5                   -110
# 27                       7.0                   7.0                   -105
# 43                       9.0                   9.0                   -120
# 45                       7.5                   7.5                   -125
# 47                       8.0                   8.0                    100
# 49                       9.0                   9.0                    100
# 53                       8.0                   8.0                    110
# 55                       8.5                   8.5                   -115
# 67                       8.5                   9.0                   -115
# 73                       8.0                   8.5                   -110
# 77                      10.5                   9.5                    105
# 103                      8.5                   9.0                   -105
# 105                      8.5                   8.5                   -110
# 115                      9.5                   9.0                   -120
# 119                      9.5                   9.5                   -105
# 125                      8.5                   8.5                   -110
# 131                      9.5                   9.5                   -115
# 139                      9.0                   8.5                   -120
# 143                      9.5                   9.0                   -110
# 145                      9.0                   9.5                    100
# 147                      8.5                   8.5                   -115
# 151                      7.5                   7.5                   -125
# 159                      9.0                   9.0                   -115
# 161                      7.5                   7.5                   -120
# 169                      7.0                   7.5                    100
# 175                      9.0                   9.0                   -110
# 179                      9.0                   9.0                   -110
# ...                      ...                   ...                    ...
# 44459                    8.5                   8.0                   -110
# 44461                    7.0                   7.0                   -105
# 44467                    8.0                   9.0                    100
# 44469                    8.5                   9.5                    100
# 44477                    7.5                   8.0                   -115
# 44489                    9.5                   9.5                   -110
# 44491                    9.0                   8.0                   -115
# 44497                    9.0                   8.5                   -120
# 44501                    8.0                   8.0                    100
# 44511                    9.0                   9.0                   -120
# 44513                    7.0                   7.5                    100
# 44515                    8.0                   7.0                   -115
# 44523                    8.0                   7.5                   -110
# 44527                    6.5                   7.0                   -110
# 44537                    8.5                   8.5                    105
# 44543                    9.0                   9.0                   -115
# 44545                    8.5                   8.5                   -105
# 44551                    8.0                   7.5                   -105
# 44557                    7.5                   8.0                    100
# 44559                    8.0                   8.5                   -105
# 44577                    7.0                   7.0                   -110
# 44581                    9.0                   9.0                   -130
# 44583                    8.5                   7.5                   -115
# 44587                    7.0                   7.0                   -110
# 44605                    8.5                   8.5                   -110
# 44611                    7.5                   7.0                   -115
# 44613                    9.0                   9.0                   -120
# 44615                    6.5                   6.5                   -120
# 44625                    9.0                   9.0                   -110
# 44639                    7.0                   7.5                    100
#
#        over_under_odds_open        pitcher  rot  run_dif_game  run_line_close  \
# 3                      -120      JLANNAN-L  902         -10.0             NaN
# 7                      -115      AHARANG-R  906          -5.0             NaN
# 9                      -110        ZDUKE-L  908           6.0             NaN
# 17                     -125      ROSWALT-R  916          -3.0             NaN
# 27                     -105      BSHEETS-R  926          -2.0             NaN
# 43                     -115       DDAVIS-L  902           1.0             NaN
# 45                     -115       BMYERS-R  904          -6.0             NaN
# 47                     -110    ROHLENDOR-R  906           1.0             NaN
# 49                     -115     JMARQUIS-R  908          -4.0             NaN
# 53                     -110       JCUETO-R  912          -3.0             NaN
# 55                     -110       JMAINE-R  914          -1.0             NaN
# 67                     -115    LHOCHEVAR-R  926           1.0             NaN
# 73                     -120      PMAHOLM-L  952          -8.0             NaN
# 77                     -105     CSTAMMEN-R  956           1.0             NaN
# 103                    -120     CVOLSTAD-R  910          -4.0             NaN
# 105                     100      BNORRIS-R  912          -8.0             NaN
# 115                    -105       DPRICE-L  922           6.0             NaN
# 119                    -110      KDAVIES-R  926           1.0             NaN
# 125                    -105      AHARANG-R  952          -1.0             NaN
# 131                    -115     FPAULINO-R  958          -3.0             NaN
# 139                     113   WELLEMEYER-R  966          -5.0             NaN
# 143                    -120      FGARCIA-R  970          -1.0             NaN
# 145                    -110       WDAVIS-R  972         -10.0             NaN
# 147                    -115    MHARRISON-L  974          -1.0             NaN
# 151                    -120     ZGREINKE-R  978          -5.0             NaN
# 159                     100       MLEAKE-R  906           2.0             NaN
# 161                    -120      ROSWALT-R  908          -1.0             NaN
# 169                    -105        RWOLF-L  916           1.0             NaN
# 175                    -105     JSHIELDS-R  922          -4.0             NaN
# 179                    -110       GMECHE-R  926          -2.0             NaN
# ...                     ...            ...  ...           ...             ...
# 44459                  -110    YCHIRINOS-R  970           2.0             1.5
# 44461                   100      MPINEDA-R  972           6.0             1.5
# 44467                  -120     WLEBLANC-L  978           2.0             1.5
# 44469                  -119        LLYNN-R  980           1.0             1.5
# 44477                  -120       CSMITH-L  908          -4.0             1.5
# 44489                  -110       DSMYLY-L  920          -1.0             1.5
# 44491                  -110      ABROOKS-R  922           7.0             1.5
# 44497                  -115  ADESCLAFANI-R  952          -1.0             1.5
# 44501                  -110       JURENA-R  956          -1.0             1.5
# 44511                  -110      SMILLER-R  966           2.0             1.5
# 44513                  -120      BKELLER-R  968          -1.0             1.5
# 44515                   100       MFIERS-R  970           1.0             1.5
# 44523                  -110     ASANCHEZ-R  904           1.0             1.5
# 44527                  -110    TRICHARDS-R  908          -2.0             1.5
# 44537                  -110      HBAILEY-R  918          -1.0             1.5
# 44543                  -110       MMINOR-L  924           4.0             1.5
# 44545                  -110     MESTRADA-R  926          -3.0             1.5
# 44551                  -101       JLYLES-R  956           2.0             1.5
# 44557                  -101        ACOBB-R  964          -4.0             1.5
# 44559                  -120    BANDERSON-L  966           4.0             1.5
# 44577                  -105   DRODRIGUEZ-R  916          -3.0             1.5
# 44581                  -101      ZGODLEY-R  920           7.0             1.5
# 44583                  -101       RLOPEZ-R  922           2.0             1.5
# 44587                  -105        SMATZ-L  952           1.0             1.5
# 44605                  -119       DBUNDY-R  972          -2.0             1.5
# 44611                  -110  JSAMARDZIJA-R  978           2.0             1.5
# 44613                  -118      LWEAVER-R  980           1.0             1.5
# 44615                  -110     ZWHEELER-R  902          -3.0             1.5
# 44625                  -120        DHESS-R  914         -12.0             1.5
# 44639                  -110    DPOMERANZ-L  928          -3.0             1.5
#
#        run_line_odds_close  run_line_win
# 3                      NaN           NaN
# 7                      NaN           NaN
# 9                      NaN           NaN
# 17                     NaN           NaN
# 27                     NaN           NaN
# 43                     NaN           NaN
# 45                     NaN           NaN
# 47                     NaN           NaN
# 49                     NaN           NaN
# 53                     NaN           NaN
# 55                     NaN           NaN
# 67                     NaN           NaN
# 73                     NaN           NaN
# 77                     NaN           NaN
# 103                    NaN           NaN
# 105                    NaN           NaN
# 115                    NaN           NaN
# 119                    NaN           NaN
# 125                    NaN           NaN
# 131                    NaN           NaN
# 139                    NaN           NaN
# 143                    NaN           NaN
# 145                    NaN           NaN
# 147                    NaN           NaN
# 151                    NaN           NaN
# 159                    NaN           NaN
# 161                    NaN           NaN
# 169                    NaN           NaN
# 175                    NaN           NaN
# 179                    NaN           NaN
# ...                    ...           ...
# 44459               -160.0           1.0
# 44461               -170.0           1.0
# 44467               -140.0           1.0
# 44469               -140.0           1.0
# 44477               -144.0          -1.0
# 44489                103.0           1.0
# 44491               -130.0           1.0
# 44497               -165.0           1.0
# 44501               -135.0           1.0
# 44511                135.0           1.0
# 44513               -130.0           1.0
# 44515               -110.0           1.0
# 44523               -135.0           1.0
# 44527               -102.0          -1.0
# 44537               -140.0           1.0
# 44543                120.0           1.0
# 44545               -134.0          -1.0
# 44551               -170.0           1.0
# 44557                120.0          -1.0
# 44559               -160.0           1.0
# 44577               -165.0          -1.0
# 44581               -139.0           1.0
# 44583               -145.0           1.0
# 44587               -145.0           1.0
# 44605                105.0          -1.0
# 44611               -145.0           1.0
# 44613               -139.0           1.0
# 44615               -145.0          -1.0
# 44625               -101.0          -1.0
# 44639               -170.0          -1.0
#
# [6553 rows x 20 columns]
