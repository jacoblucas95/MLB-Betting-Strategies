# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_pickle('portfolio.pickle')

# %%
df1 = pd.read_pickle('unix_dataset.pickle')
df1
# Out:
#                date  gameno visitor v_team  v_team_run_total  \
# 0      1.270354e+09       0       V    NYY               7.0
# 1      1.270440e+09       1       V    PHI              11.0
# 2      1.270440e+09       2       V    MIA               1.0
# 3      1.270440e+09       3       V    STL              11.0
# 4      1.270440e+09       4       V    LAD               5.0
# 5      1.270440e+09       5       V    COL               5.0
# 6      1.270440e+09       6       V    CHC               5.0
# 7      1.270440e+09       7       V     SD               3.0
# 8      1.270440e+09       8       V     SF               5.0
# 9      1.270440e+09       9       V    CLE               0.0
# 10     1.270440e+09      10       V    TOR               4.0
# 11     1.270440e+09      11       V    DET               8.0
# 12     1.270440e+09      12       V    MIN               3.0
# 13     1.270440e+09      13       V    SEA               5.0
# ...

# %%
new_list = []

df2 = df1.loc[df1['v_run_line_close'].isnull()]
df2.info()


# for index, row in df1.iterrows():
#     rl = row['v_run_line_close']
#     if rl != 'NaN':
#         new_list.append(index)
# new_list
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9865 entries, 0 to 9864
# Data columns (total 31 columns):
# date                     9865 non-null float64
# gameno                   9865 non-null int64
# visitor                  9865 non-null object
# v_team                   9865 non-null object
# v_team_run_total         9865 non-null float64
# v_money_line_close       9865 non-null float64
# v_money_line_open        9865 non-null int64
# v_run_line_close         0 non-null float64
# v_run_line_odds_close    0 non-null float64
# v_pitcher                9865 non-null object
# v_rot                    9865 non-null int64
# v_run_dif_game           9865 non-null float64
# home                     9865 non-null object
# h_team                   9865 non-null object
# h_team_run_total         9865 non-null float64
# h_money_line_close       9865 non-null float64
# h_money_line_open        9865 non-null int64
# h_run_line_close         0 non-null float64
# ...

# %%
outcomes = df.filter(like="outcome", axis=1)

# %%
recent_outcomes = outcomes[20000:]

# %%
recent_outcomes
# Out:
#        home_bet_outcomes_ml  visitor_bet_outcomes_ml  \
# 20000             -1.000000                 1.150000
# 20001             -1.000000                 0.375940
# 20002             -1.000000                 0.746269
# 20003             -1.000000                 1.400000
# 20004              0.775194                -1.000000
# 20005              0.448430                -1.000000
# 20006              0.568182                -1.000000
# 20007              0.512821                -1.000000
# 20008              1.430000                -1.000000
# 20009              1.140000                -1.000000
# 20010              0.588235                -1.000000
# 20011              1.010000                -1.000000
# 20012              0.621118                -1.000000
# 20013              0.917431                -1.000000
# 20014             -1.000000                 0.487805
# 20015              0.826446                -1.000000
# 20016             -1.000000                 0.456621
# ...

# %%
mean_daily_ret = outcomes.pct_change(1).mean()
mean_daily_ret
# Out:
# home_bet_outcomes_ml                   -1.017231
# visitor_bet_outcomes_ml                -1.013080
# favorites_bet_outcomes_ml              -1.000824
# underdogs_bet_outcomes_ml              -0.987773
# home_underdogs_ml_bet_outcomes_ml            NaN
# visitor_favorites_ml_bet_outcomes_ml         NaN
# visitor_underdogs_ml_bet_outcomes_ml         NaN
# home_favorites_ml_bet_outcomes_ml            NaN
# longshot_teams_ml_bet_outcomes_ml            NaN
# home_bet_outcomes_rl                         NaN
# visitor_bet_outcomes_rl                      NaN
# favorites_bet_outcomes_rl                    NaN
# underdogs_bet_outcomes_rl                    NaN
# home_favorites_rl_bet_outcomes_rl            NaN
# visitor_underdogs_rl_bet_outcomes_rl         NaN
# home_underdogs_rl_bet_outcomes_rl            NaN
# visitor_favorites_rl_bet_outcomes_rl         NaN
# longshot_teams_rl_bet_outcomes_rl            NaN
# overs_bet_outcomes_ou                        NaN
# ...

# %%
values.pct_change(1)
# Out:
#       home_portfolio_value_ml  visitor_portfolio_value_ml  \
# 0                         NaN                         NaN
# 1                   -0.724638                   -2.000000
# 2                   -4.212632                    2.000000
# 3                   -1.130406                   -0.508906
# 4                    8.668342                   -3.610984
# 5                   -0.822541                   -0.519924
# 6                   -3.978159                   -1.083003
# 7                   -1.696438                   -8.154880
# 8                    2.435878                    1.066447
# 9                   -1.084699                   -0.882493
# 10                   9.039892                   -7.510095
# 11                  -0.833701                   -1.442009
# 12                   8.021238                   -2.609916
# 13                   0.972508                    1.621150
# 14                  -0.281732                   -0.567420
# ...
