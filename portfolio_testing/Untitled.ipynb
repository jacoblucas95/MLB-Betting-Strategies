# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_pickle('portfolio.pickle')

# %%
df.describe()
# Out:
#              gameno  home_bet_outcomes_ml  home_portfolio_value_ml  \
# count  22326.000000          22326.000000             22326.000000
# mean   11162.500000             -0.026897            -28827.702613
# std     6445.105391              0.931486             19145.149088
# min        0.000000             -1.000000            -62123.625473
# 25%     5581.250000             -1.000000            -44412.345253
# 50%    11162.500000              0.451470            -33011.772652
# 75%    16743.750000              0.781250            -14131.719699
# max    22325.000000              3.000000              2993.007139
#
#        visitor_bet_outcomes_ml  visitor_portfolio_value_ml  \
# count             22326.000000                22326.000000
# mean                 -0.025818               -29713.155211
# std                   1.083244                15549.729698
# min                  -1.000000               -57821.656545
# 25%                  -1.000000               -44310.718975
# ...

# %%
values = df.filter(like="portfolio", axis=1)
values
# Out:
#       home_portfolio_value_ml  visitor_portfolio_value_ml  \
# 0                 -100.000000                   50.000000
# 1                  -27.536232                  -50.000000
# 2                   88.463768                 -150.000000
# 3                  -11.536232                  -73.664122
# 4                 -111.536232                  192.335878
# 5                  -19.793113                   92.335878
# 6                   58.947045                   -7.664122
# 7                  -41.052955                   54.835878
# 8                 -141.052955                  113.315410
# 9                   11.947045                   13.315410
# 10                 119.947045                  -86.684590
# 11                  19.947045                   38.315410
# 12                 179.947045                  -61.684590
# 13                 354.947045                 -161.684590
# 14                 254.947045                  -69.941471
# ...

# %%
mean_daily_ret = values.pct_change(1).mean()
mean_daily_ret
# Out:
# home_portfolio_value_ml                    0.006084
# visitor_portfolio_value_ml                 0.019119
# favorites_portfolio_value_ml              -0.133707
# underdogs_portfolio_value_ml              -0.045020
# home_underdogs_ml_portfolio_value_ml      -0.007366
# visitor_favorites_ml_portfolio_value_ml    0.138888
# visitor_underdogs_ml_portfolio_value_ml        -inf
# home_favorites_ml_portfolio_value_ml            inf
# home_portfolio_value_rl                    0.013552
# visitor_portfolio_value_rl                -0.004623
# favorites_portfolio_value_rl               0.004462
# underdogs_portfolio_value_rl               0.002746
# home_favorites_rl_portfolio_value_rl            inf
# visitor_underdogs_rl_portfolio_value_rl        -inf
# home_underdogs_rl_portfolio_value_rl      -0.012114
# visitor_favorites_rl_portfolio_value_rl    0.005734
# overs_portfolio_value_ou                  -0.064600
# unders_portfolio_value_ou                 -0.015400
# ...

# %%
values.pct_change(1)
# Out:
#       home_portfolio_value_ml  visitor_portfolio_value_ml  \
# 0                         NaN                         NaN
# 1                   -0.724638                   -2.000000
# 2                   -4.212632                    2.000000
# 3                   -1.130406                   -0.508906
# 4                    8.668342                   -3.610984
# 5                   -0.822541                   -0.519924
# 6                   -3.978159                   -1.083003
# 7                   -1.696438                   -8.154880
# 8                    2.435878                    1.066447
# 9                   -1.084699                   -0.882493
# 10                   9.039892                   -7.510095
# 11                  -0.833701                   -1.442009
# 12                   8.021238                   -2.609916
# 13                   0.972508                    1.621150
# 14                  -0.281732                   -0.567420
# ...
