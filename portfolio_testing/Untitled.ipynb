# %%
import pandas as pd

# %%
df = pd.read_pickle('portfolio.pickle')

# %%
df.tail()
# Out:
#       gameno  home_bet_outcomes_ml  home_portfolio_value_ml  \
# 2600   22321             -1.000000             -9438.802774
# 2601   22322              0.854701             -9353.332689
# 2602   22323              0.746269             -9278.705823
# 2603   22324             -1.000000             -9378.705823
# 2604   22325             -1.000000             -9478.705823
#
#       visitor_bet_outcomes_ml  visitor_portfolio_value_ml  \
# 2600                 1.060000                -3887.886475
# 2601                -1.000000                -3987.886475
# 2602                -1.000000                -4087.886475
# 2603                 0.869565                -4000.929953
# 2604                 0.943396                -3906.590330
#
#       favorites_bet_outcomes_ml  favorites_portfolio_value_ml  \
# 2600                  -1.000000                  -8956.189249
# 2601                   0.854701                  -8870.719163
# ...

# %%
lastrow = df.iloc[-1:]

# %%
# Out:
#       gameno  home_bet_outcomes_ml  home_portfolio_value_ml  \
# 2604   22325                  -1.0             -9478.705823
#
#       visitor_bet_outcomes_ml  visitor_portfolio_value_ml  \
# 2604                 0.943396                 -3906.59033
#
#       favorites_bet_outcomes_ml  favorites_portfolio_value_ml  \
# 2604                   0.943396                  -8614.796153
#
#       underdogs_bet_outcomes_ml  underdogs_portfolio_value_ml  \
# 2604                       -1.0                       -4770.5
#
#       home_underdogs_ml_bet_outcomes_ml  ...  \
# 2604                               -1.0  ...
#
#       visitor_favorites_rl_bet_outcomes_rl  \
# 2604                                  -1.0
#
#       visitor_favorites_rl_portfolio_value_rl  overs_bet_outcomes_ou  \
# 2604                            -20963.986832                   -1.0
#
#       overs_portfolio_value_ou  unders_bet_outcomes_ou  \
# 2604             -13176.127111                0.869565
#
# ...

# %%
vals_only = lastrow.filter(like="value", axis=1)
vals_only
# Out:
#       home_portfolio_value_ml  visitor_portfolio_value_ml  \
# 2604             -9478.705823                 -3906.59033
#
#       favorites_portfolio_value_ml  underdogs_portfolio_value_ml  \
# 2604                  -8614.796153                       -4770.5
#
#       home_underdogs_ml_portfolio_value_ml  \
# 2604                               -3194.5
#
#       visitor_favorites_ml_portfolio_value_ml  \
# 2604                              -2330.59033
#
#       visitor_underdogs_ml_portfolio_value_ml  \
# 2604                                  -1576.0
#
#       home_favorites_ml_portfolio_value_ml  home_portfolio_value_rl  \
# 2604                          -6284.205823             -7874.811837
#
#       visitor_portfolio_value_rl  favorites_portfolio_value_rl  \
# 2604                60759.013168                 -63059.798669
#
#       underdogs_portfolio_value_rl  home_favorites_rl_portfolio_value_rl  \
# 2604                      115944.0                         -42095.811837
#
# ...
